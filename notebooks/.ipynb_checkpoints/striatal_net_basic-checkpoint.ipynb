# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# import nest and reset the kernel (just in case it might be needed)
import nest
nest.ResetKernel()
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0
#  Built: Sep 26 2025 04:43:22
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
# Add path to NeuroWorflow
# Add the src directory to the Python path if needed
src_path = os.path.abspath(os.path.join(os.getcwd(), '../src'))
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# Import NeuroWorkflow components (custom nodes)
from neuroworkflow import WorkflowBuilder
from neuroworkflow.nodes.network.SNNbuilder_SingleNeuron import SNNbuilder_SingleNeuron
from neuroworkflow.nodes.network.SNNbuilder_Population import SNNbuilder_Population
from neuroworkflow.nodes.network.SNNbuilder_Connection import SNNbuilder_Connection
from neuroworkflow.nodes.stimulus.SNNbuilder_Stimulation import SNNbuilder_Stimulation
from neuroworkflow.nodes.stimulus.SNNbuilder_Recordable import SNNbuilder_Recordable
from neuroworkflow.nodes.simulation.SNNbuilder_Simulation import SNNbuilder_Simulation

# %%
#TODO set the correct params
#  =============== A SPN cell 
# Create an instance of the node SNNbuilder_SingleNeuron
SPN_neuron = SNNbuilder_SingleNeuron("Spiny Projection Neuron")
    
# Configure the neuron with biological parameters
SPN_neuron.configure(
    # Biological identification
    name="Spiny Projection Neuron",
    acronym="SPN",
    model_type="point_process",
    cell_class="inhibitory",
        
    # Signaling properties
    neurotransmitter_types=["GABA"],
    psp_amplitudes={"GABA": 0.4},
    rise_times={"GABA": 2.0},
        
    # Morphological properties
    dendrite_extent=300.0,  # μm
    dendrite_diameter=2.5,  # μm
        
    # Activity properties
    firing_rate_resting=[2.0, 8.0],    # Hz
    firing_rate_active=[15.0, 40.0],   # Hz
    firing_rate_maximum=[60.0, 120.0], # Hz
        
    # NEST model parameters
    nest_model="iaf_psc_alpha_multisynapse",
    #nest_model="iaf_psc_alpha",
    nest_parameters={
        "V_th": -50.0,      # Threshold potential (mV)
        "C_m": 200.0,       # Membrane capacitance (pF)
        "tau_m": 15.0,      # Membrane time constant (ms)
        "V_reset": -70.0,   # Reset potential (mV)
        "t_ref": 2.0,        # Refractory period (ms)
        "I_e": 200.0,        #external current (pA)
    },
        
    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both"    # Python and notebook formats
    )
    
print(f"Neuron: {SPN_neuron._parameters['name']} ({SPN_neuron._parameters['acronym']})")
print(f"Neuron: {SPN_neuron._parameters}")
# Out:
# Neuron: Spiny Projection Neuron (SPN)
# Neuron: {'name': 'Spiny Projection Neuron', 'acronym': 'SPN', 'model_type': 'point_process', 'cell_class': 'inhibitory', 'neurotransmitter_types': ['GABA'], 'psp_amplitudes': {'GABA': 0.4}, 'rise_times': {'GABA': 2.0}, 'dendrite_extent': 300.0, 'dendrite_diameter': 2.5, 'firing_rate_resting': [2.0, 8.0], 'firing_rate_active': [15.0, 40.0], 'firing_rate_maximum': [60.0, 120.0], 'firing_rate_disease': [0.1, 2.0], 'nest_model': 'iaf_psc_alpha_multisynapse', 'nest_parameters': {'V_th': -50.0, 'C_m': 200.0, 'tau_m': 15.0, 'V_reset': -70.0, 't_ref': 2.0, 'I_e': 200.0}, 'template_suffix': '_custom', 'execution_mode': 'both', 'script_format': 'both'}

# %%
SPN_neuron.get_info() #uncomment to check the info of a node
# Out:
# {'name': 'Spiny Projection Neuron',
#  'type': 'single_neuron_builder',
#  'description': 'Build a single neuron with biological and NEST parameters',
#  'parameters': {'name': 'Spiny Projection Neuron',
#   'acronym': 'SPN',
#   'model_type': 'point_process',
#   'cell_class': 'inhibitory',
#   'neurotransmitter_types': ['GABA'],
#   'psp_amplitudes': {'GABA': 0.4},
#   'rise_times': {'GABA': 2.0},
#   'dendrite_extent': 300.0,
#   'dendrite_diameter': 2.5,
#   'firing_rate_resting': [2.0, 8.0],
#   'firing_rate_active': [15.0, 40.0],
#   'firing_rate_maximum': [60.0, 120.0],
#   'firing_rate_disease': [0.1, 2.0],
#   'nest_model': 'iaf_psc_alpha_multisynapse',
#   'nest_parameters': {'V_th': -50.0,
#    'C_m': 200.0,
#    'tau_m': 15.0,
#    'V_reset': -70.0,
#    't_ref': 2.0,
#    'I_e': 200.0},
#   'template_suffix': '_custom',
#   'execution_mode': 'both',
#   'script_format': 'both'},
#  'optimizable_parameters': {'dendrite_extent': {'optimizable': True,
#    'range': [50.0, 500.0],
#    'constraints': {'min': 10.0, 'max': 1000.0}},
#   'dendrite_diameter': {'optimizable': True,
#    'range': [0.5, 5.0],
#    'constraints': {'min': 0.1, 'max': 10.0}}},
#  'input_ports': {'parameter_overrides': {'type': 'dict',
#    'description': 'Dictionary of parameter overrides',
#    'optional': True},
#   'nest_parameter_overrides': {'type': 'dict',
#    'description': 'Dictionary of NEST parameter overrides',
#    'optional': True}},
#  'output_ports': {'nest_neuron': {'type': 'object',
#    'description': 'Created NEST neuron object'},
#   'nest_model_name': {'type': 'str',
#    'description': 'Name of the created NEST model template'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python script code'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell code'},
#   'neuron_metadata': {'type': 'dict',
#    'description': 'Complete neuron metadata and properties'},
#   'biological_properties': {'type': 'dict',
#    'description': 'Biological properties summary'},
#   'nest_properties': {'type': 'dict',
#    'description': 'NEST model properties and parameters'}},
#  'process_steps': [{'name': 'validate_parameters',
#    'description': 'Validate all neuron parameters',
#    'inputs': ['parameter_overrides', 'nest_parameter_overrides'],
#    'outputs': ['validation_result'],
#    'method_key': 'validate_parameters'},
#   {'name': 'create_nest_neuron',
#    'description': 'Create NEST neuron object',
#    'inputs': ['validation_result'],
#    'outputs': ['nest_neuron', 'nest_model_name'],
#    'method_key': 'create_nest_neuron'},
#   {'name': 'generate_python_script',
#    'description': 'Generate Python script code',
#    'inputs': ['validation_result'],
#    'outputs': ['python_script'],
#    'method_key': 'generate_python_script'},
#   {'name': 'generate_notebook_cell',
#    'description': 'Generate Jupyter notebook cell',
#    'inputs': ['validation_result'],
#    'outputs': ['notebook_cell'],
#    'method_key': 'generate_notebook_cell'},
#   {'name': 'compile_metadata',
#    'description': 'Compile neuron metadata and properties',
#    'inputs': ['validation_result'],
#    'outputs': ['neuron_metadata', 'biological_properties', 'nest_properties'],
#    'method_key': 'compile_metadata'}],
#  'methods': {'validate_parameters': 'Validate all neuron parameters',
#   'create_nest_neuron': 'Create NEST neuron object',
#   'generate_python_script': 'Generate Python script code',
#   'generate_notebook_cell': 'Generate Jupyter notebook cell',
#   'compile_metadata': 'Compile neuron metadata and properties'}}

# %%
SPN_neuron._parameters
# Out:
# {'name': 'Spiny Projection Neuron',
#  'acronym': 'SPN',
#  'model_type': 'point_process',
#  'cell_class': 'inhibitory',
#  'neurotransmitter_types': ['GABA'],
#  'psp_amplitudes': {'GABA': 0.4},
#  'rise_times': {'GABA': 2.0},
#  'dendrite_extent': 300.0,
#  'dendrite_diameter': 2.5,
#  'firing_rate_resting': [2.0, 8.0],
#  'firing_rate_active': [15.0, 40.0],
#  'firing_rate_maximum': [60.0, 120.0],
#  'firing_rate_disease': [0.1, 2.0],
#  'nest_model': 'iaf_psc_alpha_multisynapse',
#  'nest_parameters': {'V_th': -50.0,
#   'C_m': 200.0,
#   'tau_m': 15.0,
#   'V_reset': -70.0,
#   't_ref': 2.0,
#   'I_e': 200.0},
#  'template_suffix': '_custom',
#  'execution_mode': 'both',
#  'script_format': 'both'}

# %%
# Create a population 
SPN_pop = SNNbuilder_Population('SPN_population')
    
# Configure the population parameters
SPN_pop.configure(
    name='Spiny Projection Neurons',
    acronym='SPN',
    brain_region='Striatum',
    population_size= 8000,
    tissue_reference={ #this is a free format dictionary
        'density_per_mm3': 25000,
        'tissue_volume_mm3': 0.2,
        'reference_study': 'Schüz & Palm (1989)',
        'species': 'human',
        'estimation_method': 'stereological counting'
    },
    spatial_dimensions='3D',
    spatial_bounds={
        'x': (0.0, 2.0),
        'y': (0.0, 2.0),
        'z': (0.0, 1.0)
    },
    model_type='point_process',
    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both"    # Python and notebook formats
    )
print(f"Population: {SPN_pop._parameters}")
# Out:
# Population: {'name': 'Spiny Projection Neurons', 'acronym': 'SPN', 'brain_region': 'Striatum', 'model_type': 'point_process', 'population_size': 8000, 'tissue_reference': {'density_per_mm3': 25000, 'tissue_volume_mm3': 0.2, 'reference_study': 'Schüz & Palm (1989)', 'species': 'human', 'estimation_method': 'stereological counting'}, 'spatial_dimensions': '3D', 'spatial_bounds': {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)}, 'custom_positions': None, 'mean_firing_rate': None, 'execution_mode': 'both', 'script_format': 'both'}

# %%
SPN_pop._parameters
# Out:
# {'name': 'Spiny Projection Neurons',
#  'acronym': 'SPN',
#  'brain_region': 'Striatum',
#  'model_type': 'point_process',
#  'population_size': 8000,
#  'tissue_reference': {'density_per_mm3': 25000,
#   'tissue_volume_mm3': 0.2,
#   'reference_study': 'Schüz & Palm (1989)',
#   'species': 'human',
#   'estimation_method': 'stereological counting'},
#  'spatial_dimensions': '3D',
#  'spatial_bounds': {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)},
#  'custom_positions': None,
#  'mean_firing_rate': None,
#  'execution_mode': 'both',
#  'script_format': 'both'}

# %%
#TODO set the correct params
#  =============== A ChIN cell 
# Create an instance of the node SNNbuilder_SingleNeuron
ChIN_neuron = SNNbuilder_SingleNeuron("Cholinergic Interneuron")
    
# Configure the neuron with biological parameters
ChIN_neuron.configure(
    # Biological identification
    name="Cholinergic Interneuron",
    acronym="ChIN",
    model_type="point_process",
    #cell_class="cholinergic", # cholinergic not allowed
    #cell_class="other",
    cell_class="excitatory",
    
    # Signaling properties
  #  neurotransmitter_types=["nAChRs", "mAChRs"],
  #  psp_amplitudes={"nAChRs": 0.4,"mAChRs": 0.4},
  #  rise_times={"nAChRs": 2.0, "mAChRs": 2.0},

        # Signaling properties
    neurotransmitter_types=["AMPA", "NMDA"],
    psp_amplitudes={"AMPA": 0.4,"NMDA": 0.4},
    rise_times={"AMPA": 2.0, "NMDA": 2.0},
        
        
    # Morphological properties
    dendrite_extent=300.0,  # μm
    dendrite_diameter=2.5,  # μm
        
    # Activity properties
    firing_rate_resting=[6.0, 10.0],    # Hz
    firing_rate_active=[25.0, 60.0],   # Hz
    firing_rate_maximum=[70.0, 120.0], # Hz
        
    # NEST model parameters
    nest_model="iaf_psc_alpha_multisynapse",
    #nest_model="iaf_psc_alpha",
    nest_parameters={
        "V_th": -50.0,      # Threshold potential (mV)
        "C_m": 200.0,       # Membrane capacitance (pF)
        "tau_m": 15.0,      # Membrane time constant (ms)
        "V_reset": -70.0,   # Reset potential (mV)
        "t_ref": 2.0,        # Refractory period (ms)
        "I_e": 210.0,        #external current (pA)
    },
        
    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both"    # Python and notebook formats
    )
    
print(f"Neuron: {ChIN_neuron._parameters['name']} ({ChIN_neuron._parameters['acronym']})")
print(f"Neuron: {ChIN_neuron._parameters}")
# Out:
# Neuron: Cholinergic Interneuron (ChIN)
# Neuron: {'name': 'Cholinergic Interneuron', 'acronym': 'ChIN', 'model_type': 'point_process', 'cell_class': 'excitatory', 'neurotransmitter_types': ['AMPA', 'NMDA'], 'psp_amplitudes': {'AMPA': 0.4, 'NMDA': 0.4}, 'rise_times': {'AMPA': 2.0, 'NMDA': 2.0}, 'dendrite_extent': 300.0, 'dendrite_diameter': 2.5, 'firing_rate_resting': [6.0, 10.0], 'firing_rate_active': [25.0, 60.0], 'firing_rate_maximum': [70.0, 120.0], 'firing_rate_disease': [0.1, 2.0], 'nest_model': 'iaf_psc_alpha_multisynapse', 'nest_parameters': {'V_th': -50.0, 'C_m': 200.0, 'tau_m': 15.0, 'V_reset': -70.0, 't_ref': 2.0, 'I_e': 210.0}, 'template_suffix': '_custom', 'execution_mode': 'both', 'script_format': 'both'}

# %%
ChIN_neuron.get_info()
ChIN_neuron._parameters
# Out:
# {'name': 'Cholinergic Interneuron',
#  'acronym': 'ChIN',
#  'model_type': 'point_process',
#  'cell_class': 'excitatory',
#  'neurotransmitter_types': ['AMPA', 'NMDA'],
#  'psp_amplitudes': {'AMPA': 0.4, 'NMDA': 0.4},
#  'rise_times': {'AMPA': 2.0, 'NMDA': 2.0},
#  'dendrite_extent': 300.0,
#  'dendrite_diameter': 2.5,
#  'firing_rate_resting': [6.0, 10.0],
#  'firing_rate_active': [25.0, 60.0],
#  'firing_rate_maximum': [70.0, 120.0],
#  'firing_rate_disease': [0.1, 2.0],
#  'nest_model': 'iaf_psc_alpha_multisynapse',
#  'nest_parameters': {'V_th': -50.0,
#   'C_m': 200.0,
#   'tau_m': 15.0,
#   'V_reset': -70.0,
#   't_ref': 2.0,
#   'I_e': 210.0},
#  'template_suffix': '_custom',
#  'execution_mode': 'both',
#  'script_format': 'both'}

# %%
# Create a population 
ChIN_pop = SNNbuilder_Population('ChIN_population')
    
# Configure the population parameters
ChIN_pop.configure(
    name='Cholinergic Interneurons',
    acronym='ChIN',
    brain_region='Striatum',
    population_size= 150,
    tissue_reference={ #this is a free format dictionary
        'density_per_mm3': 25000,
        'tissue_volume_mm3': 0.2,
        'reference_study': 'Schüz & Palm (1989)',
        'species': 'human',
        'estimation_method': 'stereological counting'
    },
    spatial_dimensions='3D',
    spatial_bounds={
        'x': (0.0, 2.0),
        'y': (0.0, 2.0),
        'z': (0.0, 1.0)
    },
    model_type='point_process',
    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both"    # Python and notebook formats
    )
print(f"Population: {ChIN_pop._parameters}")
# Out:
# Population: {'name': 'Cholinergic Interneurons', 'acronym': 'ChIN', 'brain_region': 'Striatum', 'model_type': 'point_process', 'population_size': 150, 'tissue_reference': {'density_per_mm3': 25000, 'tissue_volume_mm3': 0.2, 'reference_study': 'Schüz & Palm (1989)', 'species': 'human', 'estimation_method': 'stereological counting'}, 'spatial_dimensions': '3D', 'spatial_bounds': {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)}, 'custom_positions': None, 'mean_firing_rate': None, 'execution_mode': 'both', 'script_format': 'both'}

# %%
ChIN_pop._parameters
# Out:
# {'name': 'Cholinergic Interneurons',
#  'acronym': 'ChIN',
#  'brain_region': 'Striatum',
#  'model_type': 'point_process',
#  'population_size': 150,
#  'tissue_reference': {'density_per_mm3': 25000,
#   'tissue_volume_mm3': 0.2,
#   'reference_study': 'Schüz & Palm (1989)',
#   'species': 'human',
#   'estimation_method': 'stereological counting'},
#  'spatial_dimensions': '3D',
#  'spatial_bounds': {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)},
#  'custom_positions': None,
#  'mean_firing_rate': None,
#  'execution_mode': 'both',
#  'script_format': 'both'}

# %%
# Create a workflow builder
workflow = WorkflowBuilder("Simple population of spiking neurons")

# Add nodes to the workflow
workflow.add_node(SPN_neuron)
workflow.add_node(ChIN_neuron)
workflow.add_node(SPN_pop)
workflow.add_node(ChIN_pop)

# %%
# Get port names from any node instance

SPN_neuron_output_ports = list(SPN_neuron.get_info()['output_ports'].keys())  
print(f"Neuron output ports: {SPN_neuron_output_ports}")

print(f"Population input ports: {SPN_pop.get_info()['input_ports'].keys()}")
# Out:
# Neuron output ports: ['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties']
# Population input ports: dict_keys(['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties'])

# %%
#Get port names from any node instance

ChIN_neuron_output_ports = list(ChIN_neuron.get_info()['output_ports'].keys())  
print(f"Neuron output ports: {ChIN_neuron_output_ports}")

print(f"Population input ports: {ChIN_pop.get_info()['input_ports'].keys()}")
# Out:
# Neuron output ports: ['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties']
# Population input ports: dict_keys(['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties'])

# %%
# Connect the nodes by ports

workflow.connect(
    SPN_neuron.name, SPN_neuron_output_ports[1], 
    SPN_pop.name, "nest_model_name"
)
workflow.connect(
    SPN_neuron.name, SPN_neuron_output_ports[-2], 
    SPN_pop.name, "biological_properties"
)
workflow.connect(
    ChIN_neuron.name, ChIN_neuron_output_ports[1], 
    ChIN_pop.name, "nest_model_name"
)
workflow.connect(
    ChIN_neuron.name, ChIN_neuron_output_ports[-2], 
    ChIN_pop.name, "biological_properties"
)

# %%
# count the connection number in the workflow
workflow.get_connection_count()
# Out:
# 4

# %%
# Create a connection
SPN_ChIN_connect = SNNbuilder_Connection('connection from SPNs to ChINs.')
    
# Configure the connection rule parameters

SPN_ChIN_connect.configure(
    name='SPN_ChIN indegree',
    connection_rule='fixed_indegree',
    connection_dict={'allow_autapses': False}, 
    synapse_model= 'static_synapse',
    synapse_dict= {'weight': 4.0, 'delay': 1.0},

    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both",    # Python and notebook formats

    redundancy=100.0 #to adjust the indegree
    )
print(f"Rule: {SPN_ChIN_connect._parameters}")
# Out:
# Rule: {'name': 'SPN_ChIN indegree', 'connection_rule': 'fixed_indegree', 'connection_dict': {'allow_autapses': False}, 'synapse_model': 'static_synapse', 'synapse_dict': {'weight': 4.0, 'delay': 1.0}, 'template_suffix': '_custom', 'axon_organization': 'focused', 'axon_radius': 0.5, 'mask_type': 'circular', 'projection_percentage': 100.0, 'bouton_number': 50, 'receptor_location': None, 'redundancy': 100.0, 'execution_mode': 'both', 'script_format': 'both'}

# %%
SPN_ChIN_connect.get_info()
# Out:
# {'name': 'connection from SPNs to ChINs.',
#  'type': 'connection_builder',
#  'description': 'Creates neural connections between populations with biological and spatial parameters',
#  'parameters': {'name': 'SPN_ChIN indegree',
#   'connection_rule': 'fixed_indegree',
#   'connection_dict': {'allow_autapses': False},
#   'synapse_model': 'static_synapse',
#   'synapse_dict': {'weight': 4.0, 'delay': 1.0},
#   'template_suffix': '_custom',
#   'axon_organization': 'focused',
#   'axon_radius': 0.5,
#   'mask_type': 'circular',
#   'projection_percentage': 100.0,
#   'bouton_number': 50,
#   'receptor_location': None,
#   'redundancy': 100.0,
#   'execution_mode': 'both',
#   'script_format': 'both'},
#  'optimizable_parameters': {'axon_radius': {'optimizable': True,
#    'range': [0.1, 2.0],
#    'constraints': {'min': 0.01}},
#   'projection_percentage': {'optimizable': True,
#    'range': [10.0, 100.0],
#    'constraints': {'min': 0.0, 'max': 100.0}},
#   'bouton_number': {'optimizable': True,
#    'range': [10, 200],
#    'constraints': {'min': 1}},
#   'receptor_location': {'optimizable': True,
#    'range': [0.0, 1.0],
#    'constraints': {'min': 0.0, 'max': 1.0}},
#   'redundancy': {'optimizable': True,
#    'range': [1.0, 10.0],
#    'constraints': {'min': 1.0}}},
#  'input_ports': {'source_nest_population': {'type': 'object',
#    'description': 'Source NEST population object',
#    'optional': True},
#   'source_population_metadata': {'type': 'dict',
#    'description': 'Source population metadata and properties',
#    'optional': True},
#   'source_neuron_properties': {'type': 'dict',
#    'description': 'Source neuron biological properties (including PSP data)',
#    'optional': True},
#   'target_nest_population': {'type': 'object',
#    'description': 'Target NEST population object',
#    'optional': True},
#   'target_population_metadata': {'type': 'dict',
#    'description': 'Target population metadata and properties',
#    'optional': True},
#   'target_neuron_properties': {'type': 'dict',
#    'description': 'Target neuron biological properties',
#    'optional': True},
#   'connection_parameter_overrides': {'type': 'dict',
#    'description': 'Dictionary of connection parameter overrides',
#    'optional': True}},
#  'output_ports': {'nest_connections': {'type': 'object',
#    'description': 'Created NEST connection object'},
#   'custom_synapse_model': {'type': 'str',
#    'description': 'Name of the created custom synapse model'},
#   'connection_summary': {'type': 'dict',
#    'description': 'Summary of created connections and parameters'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python script for connection creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell'}},
#  'process_steps': [{'name': 'validate_parameters',
#    'description': 'Validate connection parameters and inputs',
#    'inputs': ['connection_parameter_overrides'],
#    'outputs': ['validated_params'],
#    'method_key': 'validate_parameters'},
#   {'name': 'create_custom_synapse',
#    'description': 'Create custom synapse model with parameter overrides',
#    'inputs': ['validated_params'],
#    'outputs': ['custom_synapse_model'],
#    'method_key': 'create_custom_synapse'},
#   {'name': 'create_nest_connections',
#    'description': 'Create NEST connections using validated parameters',
#    'inputs': ['validated_params', 'custom_synapse_model'],
#    'outputs': ['nest_connections', 'connection_summary'],
#    'method_key': 'create_nest_connections'},
#   {'name': 'generate_python_script',
#    'description': 'Generate Python script for connection creation',
#    'inputs': ['validated_params'],
#    'outputs': ['python_script'],
#    'method_key': 'generate_python_script'},
#   {'name': 'generate_notebook_cell',
#    'description': 'Generate Jupyter notebook cell for connection creation',
#    'inputs': ['validated_params'],
#    'outputs': ['notebook_cell'],
#    'method_key': 'generate_notebook_cell'}],
#  'methods': {'validate_parameters': 'Validate connection parameters and inputs',
#   'create_custom_synapse': 'Create custom synapse model with parameter overrides',
#   'create_nest_connections': 'Create NEST connections using validated parameters',
#   'generate_python_script': 'Generate Python script for connection creation',
#   'generate_notebook_cell': 'Generate Jupyter notebook cell for connection creation'}}

# %%
ChIN_SPN_connect = SNNbuilder_Connection('connection from ChINs to SPNs.')
    
# Configure the connection rule parameters

ChIN_SPN_connect.configure(
    name='ChIN_SPN indegree',
    connection_rule='fixed_indegree',
    connection_dict={'allow_autapses': False}, 
    synapse_model= 'static_synapse',
    synapse_dict= {'weight': 10.0, 'delay': 1.0},

    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both",    # Python and notebook formats

    redundancy=100.0 #to adjust the indegree
    )
print(f"Rule: {ChIN_SPN_connect._parameters}")
# Out:
# Rule: {'name': 'ChIN_SPN indegree', 'connection_rule': 'fixed_indegree', 'connection_dict': {'allow_autapses': False}, 'synapse_model': 'static_synapse', 'synapse_dict': {'weight': 10.0, 'delay': 1.0}, 'template_suffix': '_custom', 'axon_organization': 'focused', 'axon_radius': 0.5, 'mask_type': 'circular', 'projection_percentage': 100.0, 'bouton_number': 50, 'receptor_location': None, 'redundancy': 100.0, 'execution_mode': 'both', 'script_format': 'both'}

# %%
workflow.add_node(SPN_ChIN_connect)
workflow.add_node(ChIN_SPN_connect)

# %%
SPN_pop.get_info()['output_ports'], SPN_ChIN_connect.get_info()['input_ports']
# Out:
# ({'nest_population': {'type': 'object',
#    'description': 'NEST population object (if execution mode)'},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata and configuration'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python code for population creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell code for population creation'}},
#  {'source_nest_population': {'type': 'object',
#    'description': 'Source NEST population object',
#    'optional': True},
#   'source_population_metadata': {'type': 'dict',
#    'description': 'Source population metadata and properties',
#    'optional': True},
#   'source_neuron_properties': {'type': 'dict',
#    'description': 'Source neuron biological properties (including PSP data)',
#    'optional': True},
#   'target_nest_population': {'type': 'object',
#    'description': 'Target NEST population object',
#    'optional': True},
#   'target_population_metadata': {'type': 'dict',
#    'description': 'Target population metadata and properties',
#    'optional': True},
#   'target_neuron_properties': {'type': 'dict',
#    'description': 'Target neuron biological properties',
#    'optional': True},
#   'connection_parameter_overrides': {'type': 'dict',
#    'description': 'Dictionary of connection parameter overrides',
#    'optional': True}})

# %%
workflow.connect( 
    SPN_pop.name, "nest_population",
    SPN_ChIN_connect.name, "source_nest_population")
workflow.connect( 
    SPN_pop.name, "population_data",
    SPN_ChIN_connect.name, "source_population_metadata")

workflow.connect( 
    ChIN_pop.name, "nest_population",
    SPN_ChIN_connect.name, "target_nest_population")
workflow.connect( 
    ChIN_pop.name, "population_data",
    SPN_ChIN_connect.name, "target_population_metadata")

# %%
workflow.connect( 
    ChIN_pop.name, "nest_population",
    ChIN_SPN_connect.name, "source_nest_population")
workflow.connect( 
    ChIN_pop.name, "population_data",
    ChIN_SPN_connect.name, "source_population_metadata")

workflow.connect( 
    SPN_pop.name, "nest_population",
    ChIN_SPN_connect.name, "target_nest_population")
workflow.connect( 
    SPN_pop.name, "population_data",
    ChIN_SPN_connect.name, "target_population_metadata")

# %%
workflow.get_connection_count()
# Out:
# 12

# %%
#Create a stimulus
stim_pg = SNNbuilder_Stimulation("poisson_stimulation noise")

# %%
# defaul parameters
#stim_pg._parameters

# %%
# Define parameters
stim_pg.configure(
    # Stimulation type and devices
    stimulation_type= 'poisson_generator',
    number_of_devices= 1,
        
    # Poisson generator parameters
    poisson_parameters= {
        'rate': 50.0,      # Hz
        'start': 100.0,    # ms
        'stop': 900.0      # ms
    },
        
    # Target all neurons in population
    target_identification= 'full_population',
        
    # Synapse specification
   # synapse_specification= {
   #         'synapse_model': 'static_synapse',
   #         'weight': 2.5,     # pA
    #        'delay': 1.5       # ms
    #    },
    synapse_specification= {
            'synapse_model': 'static_synapse',
            'weight': 2.5,     # pA
            'delay': 1.5,       # ms
            'receptor_type': 1
        },
        
    
        # Template and execution options
        template_suffix= '_custom',
        script_format= 'both',        # Generate both script and notebook
        execution_mode= 'both' #  Execute and generate script
    )

print(f"Stimulus: {stim_pg._parameters}")
# Out:
# Stimulus: {'stimulation_type': 'poisson_generator', 'number_of_devices': 1, 'poisson_parameters': {'rate': 50.0, 'start': 100.0, 'stop': 900.0}, 'dc_parameters': {'label': 'dc_stim', 'start': 0.0, 'stop': 1000.0, 'amplitude': 100.0}, 'synapse_specification': {'synapse_model': 'static_synapse', 'weight': 2.5, 'delay': 1.5, 'receptor_type': 1}, 'target_identification': 'full_population', 'volume_area_specification': {'center_coordinates': [0.0, 0.0, 0.0], 'radius': 0.5}, 'execution_mode': 'both', 'script_format': 'both', 'template_suffix': '_custom'}

# %%
#Create a stimulus
stim_dc = SNNbuilder_Stimulation("direct current stimulation")

stim_dc.configure(
    # Stimulation type and devices
    stimulation_type= 'dc_generator',
    number_of_devices= 1, #always 1 for DC generator

    #dc parameters
    dc_parameters= {
        'label': 'dc_stim',
        'start': 500.0,
        'stop': 700.0,
        'amplitude': 100.0
    },
        
    # Target all neurons in population
    target_identification= 'full_population',
  #  target_identification= 'define_volume_area',
  #  volume_area_specification= {
  #      'center_coordinates': [0.0, 0.0, 0.0],
  #      'radius': 0.5
  #  },

    script_format= 'both',        # Generate both script and notebook
    execution_mode= 'both' #  Execute and generate script
)

print(f"Stimulus: {stim_dc._parameters}")
# Out:
# Stimulus: {'stimulation_type': 'dc_generator', 'number_of_devices': 1, 'poisson_parameters': {'label': 'poisson_stim', 'start': 0.0, 'stop': 1000.0, 'rate': 100.0}, 'dc_parameters': {'label': 'dc_stim', 'start': 500.0, 'stop': 700.0, 'amplitude': 100.0}, 'synapse_specification': {'synapse_model': 'static_synapse', 'weight': 1.0, 'delay': 1.0}, 'target_identification': 'full_population', 'volume_area_specification': {'center_coordinates': [0.0, 0.0, 0.0], 'radius': 0.5}, 'execution_mode': 'both', 'script_format': 'both', 'template_suffix': '_custom'}

# %%
workflow.add_node(stim_pg)
workflow.add_node(stim_dc)

# %%
SPN_pop.get_info()['output_ports'], stim_pg.get_info()['input_ports']
# Out:
# ({'nest_population': {'type': 'object',
#    'description': 'NEST population object (if execution mode)'},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata and configuration'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python code for population creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell code for population creation'}},
#  {'nest_population': {'type': 'object',
#    'description': 'NEST population object to stimulate',
#    'optional': False},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata including spatial information',
#    'optional': False}})

# %%
ChIN_pop.get_info()['output_ports'], stim_pg.get_info()['input_ports']
# Out:
# ({'nest_population': {'type': 'object',
#    'description': 'NEST population object (if execution mode)'},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata and configuration'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python code for population creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell code for population creation'}},
#  {'nest_population': {'type': 'object',
#    'description': 'NEST population object to stimulate',
#    'optional': False},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata including spatial information',
#    'optional': False}})

# %%
workflow.connect( 
    ChIN_pop.name, "nest_population",
    stim_pg.name, "nest_population")
workflow.connect( 
    ChIN_pop.name, "population_data",
    stim_pg.name, "population_data")

workflow.connect( 
    ChIN_pop.name, "nest_population",
    stim_dc.name, "nest_population")
workflow.connect( 
    ChIN_pop.name, "population_data",
    stim_dc.name, "population_data")

# %%
workflow.get_connection_count()
# Out:
# 16

# %%
#Create a recordable for exc. population
sp_SPN = SNNbuilder_Recordable("spike detector for SPN pop")

sp_SPN.configure(
    # recording type and devices
    recording_type= 'spike_recorder',

    #spike_recorder parameters
    spike_recorder_parameters= {
        'record_to': 'ascii',
        'start': 0.0,
        'stop': 1000.0,
    },
        
    # Target all neurons in population
    target_identification= 'full_population',

    script_format= 'both',        # Generate both script and notebook
    execution_mode= 'both' #  Execute and generate script
)

print(f"Stimulus: {sp_SPN._parameters}")
# Out:
# Stimulus: {'recording_type': 'spike_recorder', 'number_of_devices': 1, 'spike_recorder_parameters': {'record_to': 'ascii', 'start': 0.0, 'stop': 1000.0}, 'target_identification': 'full_population', 'volume_area_specification': {'center_coordinates': [0.0, 0.0, 0.0], 'radius': 0.5}, 'script_format': 'both', 'execution_mode': 'both'}

# %%
#Create a recordable for exc. population
sp_ChIN = SNNbuilder_Recordable("spike detector for ChIN pop")

sp_ChIN.configure(
    # recording type and devices
    recording_type= 'spike_recorder',

    #spike_recorder parameters
    spike_recorder_parameters= {
        'record_to': 'ascii',
        'start': 0.0,
        'stop': 1000.0,
    },
        
    # Target all neurons in population
    target_identification= 'full_population',

    script_format= 'both',        # Generate both script and notebook
    execution_mode= 'both' #  Execute and generate script
)

print(f"Stimulus: {sp_ChIN._parameters}")
# Out:
# Stimulus: {'recording_type': 'spike_recorder', 'number_of_devices': 1, 'spike_recorder_parameters': {'record_to': 'ascii', 'start': 0.0, 'stop': 1000.0}, 'target_identification': 'full_population', 'volume_area_specification': {'center_coordinates': [0.0, 0.0, 0.0], 'radius': 0.5}, 'script_format': 'both', 'execution_mode': 'both'}

# %%
ChIN_pop.get_info()['output_ports'], sp_ChIN.get_info()['input_ports']
# Out:
# ({'nest_population': {'type': 'object',
#    'description': 'NEST population object (if execution mode)'},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata and configuration'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python code for population creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell code for population creation'}},
#  {'nest_population': {'type': 'object',
#    'description': 'NEST population object to record from',
#    'optional': False},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata including spatial information',
#    'optional': False}})

# %%
workflow.add_node(sp_SPN)
workflow.add_node(sp_ChIN)

# %%
workflow.connect( 
    SPN_pop.name, "nest_population",
    sp_SPN.name, "nest_population")
workflow.connect( 
    SPN_pop.name, "population_data",
    sp_SPN.name, "population_data")

workflow.connect( 
    ChIN_pop.name, "nest_population",
    sp_ChIN.name, "nest_population")
workflow.connect( 
    ChIN_pop.name, "population_data",
    sp_ChIN.name, "population_data")

# %%
workflow.get_connection_count()
# Out:
# 20

# %%
# Build the workflow
workflow_ready = workflow.build()

# Print workflow information
print(workflow_ready)
# Out:
# Workflow: Simple population of spiking neurons
# Nodes:
#   Spiny Projection Neuron
#   Cholinergic Interneuron
#   SPN_population
#   ChIN_population
#   connection from SPNs to ChINs.
#   connection from ChINs to SPNs.
#   poisson_stimulation noise
#   direct current stimulation
#   spike detector for SPN pop
#   spike detector for ChIN pop
# Connections:
#   Spiny Projection Neuron.nest_model_name -> SPN_population.nest_model_name
#   Spiny Projection Neuron.biological_properties -> SPN_population.biological_properties
#   Cholinergic Interneuron.nest_model_name -> ChIN_population.nest_model_name
#   Cholinergic Interneuron.biological_properties -> ChIN_population.biological_properties
#   SPN_population.nest_population -> connection from SPNs to ChINs..source_nest_population
#   SPN_population.population_data -> connection from SPNs to ChINs..source_population_metadata
#   ChIN_population.nest_population -> connection from SPNs to ChINs..target_nest_population
#   ChIN_population.population_data -> connection from SPNs to ChINs..target_population_metadata
#   ChIN_population.nest_population -> connection from ChINs to SPNs..source_nest_population
#   ChIN_population.population_data -> connection from ChINs to SPNs..source_population_metadata
#   SPN_population.nest_population -> connection from ChINs to SPNs..target_nest_population
#   SPN_population.population_data -> connection from ChINs to SPNs..target_population_metadata
#   ChIN_population.nest_population -> poisson_stimulation noise.nest_population
#   ChIN_population.population_data -> poisson_stimulation noise.population_data
#   ChIN_population.nest_population -> direct current stimulation.nest_population
#   ChIN_population.population_data -> direct current stimulation.population_data
#   SPN_population.nest_population -> spike detector for SPN pop.nest_population
#   SPN_population.population_data -> spike detector for SPN pop.population_data
#   ChIN_population.nest_population -> spike detector for ChIN pop.nest_population
#   ChIN_population.population_data -> spike detector for ChIN pop.population_data

# %%
# Execute the workflow
print("Executing workflow...")
success = workflow_ready.execute()

if success:
    print("\nWorkflow execution completed successfully!")
else:
    print("\nWorkflow execution failed!")
# Out:
# Executing workflow...
# Executing node: Cholinergic Interneuron
# [Cholinergic Interneuron] Validating neuron parameters...
# [Cholinergic Interneuron] Parameter validation completed successfully
# [Cholinergic Interneuron] Creating NEST neuron...
# [Cholinergic Interneuron] Copying model: iaf_psc_alpha_multisynapse -> iaf_psc_alpha_multisynapse_ChIN_custom
# [Cholinergic Interneuron] Multisynapse model detected: mapping PSP rise times to tau_syn = (2.0, 2.0)
# [Cholinergic Interneuron] Neurotransmitter mapping: {'AMPA': 2.0, 'NMDA': 2.0}
# [Cholinergic Interneuron] Setting defaults: {'V_th': -50.0, 'C_m': 200.0, 'tau_m': 15.0, 'V_reset': -70.0, 't_ref': 2.0, 'I_e': 210.0, 'tau_syn': (2.0, 2.0)}
# [Cholinergic Interneuron] Creating neuron from template: iaf_psc_alpha_multisynapse_ChIN_custom
# [Cholinergic Interneuron] NEST neuron created successfully: NodeCollection(metadata=None, model=iaf_psc_alpha_multisynapse_ChIN_custom, size=1, first=1)
# [Cholinergic Interneuron] Generating Python script...
# [Cholinergic Interneuron] Python script generated (28 lines)
# [Cholinergic Interneuron] Generating Jupyter notebook cell...
# [Cholinergic Interneuron] Generating Python script...
# [Cholinergic Interneuron] Python script generated (28 lines)
# [Cholinergic Interneuron] Notebook cell generated
# [Cholinergic Interneuron] Compiling neuron metadata...
# [Cholinergic Interneuron] Metadata compilation completed
# Executing node: ChIN_population
# [ChIN_population] Validating population parameters...
# [ChIN_population] Generated random 3D positions for 150 neurons
# [ChIN_population] Parameter validation completed successfully
# [ChIN_population] Creating NEST population...
# [ChIN_population] Creating 150 neurons of type 'iaf_psc_alpha_multisynapse_ChIN_custom'
# [ChIN_population] Create NEST population with generated positions from helper method
# [ChIN_population] Population created with 3D spatial positions
# [ChIN_population] Status of first neuron: ({'archiver_length': 0, 'beta_Ca': 0.001, 'C_m': 200.0, 'Ca': 0.0, 'E_L': -70.0, 'element_type': 'neuron', 'frozen': False, 'global_id': 2, 'has_connections': False, 'I_e': 210.0, 'local': True, 'model': 'iaf_psc_alpha_multisynapse_ChIN_custom', 'model_id': 106, 'n_synapses': 2, 'node_uses_wfr': False, 'post_trace': 0.0, 'recordables': ('I_syn', 'V_m', 'I_syn_1', 'I_syn_2'), 'synaptic_elements': {}, 't_ref': 2.0, 't_spike': -1.0, 'tau_Ca': 10000.0, 'tau_m': 15.0, 'tau_minus': 20.0, 'tau_minus_triplet': 110.0, 'tau_syn': (2.0, 2.0), 'thread': 0, 'thread_local_id': -1, 'V_m': -70.0, 'V_min': -inf, 'V_reset': -70.0, 'V_th': -50.0, 'vp': 0},)
# [ChIN_population] NEST population created successfully: NodeCollection(metadata=spatial, model=iaf_psc_alpha_multisynapse_ChIN_custom, size=150, first=2, last=151)
# [ChIN_population] Generating Python script...
# [ChIN_population] Python script generated (42 lines)
# [ChIN_population] Generating Jupyter notebook cell...
# [ChIN_population] Notebook cell generated (9 lines)
# Executing node: spike detector for ChIN pop
# [spike detector for ChIN pop] Validating recording parameters...
# [spike detector for ChIN pop] Parameter validation completed successfully
# [spike detector for ChIN pop] Creating recording devices...
# [spike detector for ChIN pop] Created 1 spike_recorder device(s)
# [spike detector for ChIN pop] Skipping target identification (execution_mode: both)
# [spike detector for ChIN pop] Creating connections...
# [spike detector for ChIN pop] Connected 150 neurons to 1 recording device(s)
# [spike detector for ChIN pop] Total connections: 150
# [spike detector for ChIN pop] Generating Python script...
# [spike detector for ChIN pop] Python script generated (28 lines)
# [spike detector for ChIN pop] Generating Python script...
# [spike detector for ChIN pop] Python script generated (28 lines)
# Warning: Expected output 'recording_summary' not produced by process step 'compile_summary' (method: compile_summary)
# Executing node: direct current stimulation
# [direct current stimulation] Validating stimulation parameters...
# [direct current stimulation] Parameter validation completed successfully
# [direct current stimulation] Creating stimulation devices...
# [direct current stimulation] Custom synapse model 'static_synapse_custom_direct_current_stimulation' created successfully
# [direct current stimulation] Created 1 dc_generator device(s)
# [direct current stimulation] Successfully created 1 stimulation device(s)
# [direct current stimulation] Identifying target neurons...
# [direct current stimulation] Targeting full population (150 neurons)
# [direct current stimulation] Creating connections...
# [direct current stimulation] Connected DC generator to 150 target neurons (direct current injection)
# [direct current stimulation] Successfully created 150 connections
# [direct current stimulation] Generating Python script...
# [direct current stimulation] Python script generated (28 lines)
# [direct current stimulation] Generating Jupyter notebook cell...
# [direct current stimulation] Generating Python script...
# [direct current stimulation] Python script generated (28 lines)
# [direct current stimulation] Notebook cell generated
# [direct current stimulation] Compiling stimulation summary...
# [direct current stimulation] Stimulation summary compiled
# Executing node: poisson_stimulation noise
# [poisson_stimulation noise] Validating stimulation parameters...
# [poisson_stimulation noise] Parameter validation completed successfully
# [poisson_stimulation noise] Creating stimulation devices...
# [poisson_stimulation noise] Custom synapse model 'static_synapse_custom_poisson_stimulation_noise' created successfully
# [poisson_stimulation noise] Created 1 poisson_generator device(s)
# [poisson_stimulation noise] Successfully created 1 stimulation device(s)
# [poisson_stimulation noise] Identifying target neurons...
# [poisson_stimulation noise] Targeting full population (150 neurons)
# [poisson_stimulation noise] Creating connections...
# [poisson_stimulation noise] Connected 1 Poisson device to 150 target neurons
# [poisson_stimulation noise] Successfully created 150 connections
# [poisson_stimulation noise] Generating Python script...
# [poisson_stimulation noise] Python script generated (41 lines)
# [poisson_stimulation noise] Generating Jupyter notebook cell...
# [poisson_stimulation noise] Generating Python script...
# [poisson_stimulation noise] Python script generated (41 lines)
# [poisson_stimulation noise] Notebook cell generated
# [poisson_stimulation noise] Compiling stimulation summary...
# [poisson_stimulation noise] Stimulation summary compiled
# Executing node: Spiny Projection Neuron
# [Spiny Projection Neuron] Validating neuron parameters...
# [Spiny Projection Neuron] Parameter validation completed successfully
# [Spiny Projection Neuron] Creating NEST neuron...
# [Spiny Projection Neuron] Copying model: iaf_psc_alpha_multisynapse -> iaf_psc_alpha_multisynapse_SPN_custom
# [Spiny Projection Neuron] Multisynapse model detected: mapping PSP rise times to tau_syn = (2.0,)
# [Spiny Projection Neuron] Neurotransmitter mapping: {'GABA': 2.0}
# [Spiny Projection Neuron] Setting defaults: {'V_th': -50.0, 'C_m': 200.0, 'tau_m': 15.0, 'V_reset': -70.0, 't_ref': 2.0, 'I_e': 200.0, 'tau_syn': (2.0,)}
# [Spiny Projection Neuron] Creating neuron from template: iaf_psc_alpha_multisynapse_SPN_custom
# [Spiny Projection Neuron] NEST neuron created successfully: NodeCollection(metadata=None, model=iaf_psc_alpha_multisynapse_SPN_custom, size=1, first=155)
# [Spiny Projection Neuron] Generating Python script...
# [Spiny Projection Neuron] Python script generated (27 lines)
# [Spiny Projection Neuron] Generating Jupyter notebook cell...
# [Spiny Projection Neuron] Generating Python script...
# [Spiny Projection Neuron] Python script generated (27 lines)
# [Spiny Projection Neuron] Notebook cell generated
# [Spiny Projection Neuron] Compiling neuron metadata...
# [Spiny Projection Neuron] Metadata compilation completed
# Executing node: SPN_population
# [SPN_population] Validating population parameters...
#
# Jan 30 16:27:17 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
# [SPN_population] Generated random 3D positions for 8000 neurons
# [SPN_population] Parameter validation completed successfully
# [SPN_population] Creating NEST population...
# [SPN_population] Creating 8000 neurons of type 'iaf_psc_alpha_multisynapse_SPN_custom'
# [SPN_population] Create NEST population with generated positions from helper method
# [SPN_population] Population created with 3D spatial positions
# [SPN_population] Status of first neuron: ({'archiver_length': 0, 'beta_Ca': 0.001, 'C_m': 200.0, 'Ca': 0.0, 'E_L': -70.0, 'element_type': 'neuron', 'frozen': False, 'global_id': 156, 'has_connections': False, 'I_e': 200.0, 'local': True, 'model': 'iaf_psc_alpha_multisynapse_SPN_custom', 'model_id': 107, 'n_synapses': 1, 'node_uses_wfr': False, 'post_trace': 0.0, 'recordables': ('I_syn', 'V_m', 'I_syn_1'), 'synaptic_elements': {}, 't_ref': 2.0, 't_spike': -1.0, 'tau_Ca': 10000.0, 'tau_m': 15.0, 'tau_minus': 20.0, 'tau_minus_triplet': 110.0, 'tau_syn': (2.0,), 'thread': 0, 'thread_local_id': -1, 'V_m': -70.0, 'V_min': -inf, 'V_reset': -70.0, 'V_th': -50.0, 'vp': 0},)
# [SPN_population] NEST population created successfully: NodeCollection(metadata=spatial, model=iaf_psc_alpha_multisynapse_SPN_custom, size=8000, first=156, last=8155)
# [SPN_population] Generating Python script...
# [SPN_population] Python script generated (42 lines)
# [SPN_population] Generating Jupyter notebook cell...
# [SPN_population] Notebook cell generated (9 lines)
# Executing node: spike detector for SPN pop
# [spike detector for SPN pop] Validating recording parameters...
# [spike detector for SPN pop] Parameter validation completed successfully
# [spike detector for SPN pop] Creating recording devices...
# [spike detector for SPN pop] Created 1 spike_recorder device(s)
# [spike detector for SPN pop] Skipping target identification (execution_mode: both)
# [spike detector for SPN pop] Creating connections...
#
# Jan 30 16:27:17 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
# [spike detector for SPN pop] Connected 8000 neurons to 1 recording device(s)
# [spike detector for SPN pop] Total connections: 8000
# [spike detector for SPN pop] Generating Python script...
# [spike detector for SPN pop] Python script generated (28 lines)
# [spike detector for SPN pop] Generating Python script...
# [spike detector for SPN pop] Python script generated (28 lines)
# Warning: Expected output 'recording_summary' not produced by process step 'compile_summary' (method: compile_summary)
# Executing node: connection from ChINs to SPNs.
# [connection from ChINs to SPNs.] Validating connection parameters...
# [connection from ChINs to SPNs.] Parameter validation completed successfully
# [connection from ChINs to SPNs.] Creating custom synapse model...
# [connection from ChINs to SPNs.] Copying synapse model: static_synapse -> static_synapse_custom_connection_from_ChINs_to_SPNs.
# [connection from ChINs to SPNs.] Custom synapse model 'static_synapse_custom_connection_from_ChINs_to_SPNs.' created successfully
# [connection from ChINs to SPNs.] Creating NEST connections...
# [connection from ChINs to SPNs.] Indegree calculation: P=1.00, Ny=150, Nx=8000, alpha=50, rho=100.00
# [connection from ChINs to SPNs.] Base formula: 1.00 * (150/8000) * 50 = 0.94
# [connection from ChINs to SPNs.] Redundancy adjustment: 0.94 / 100.00 = 1
# [connection from ChINs to SPNs.] Final indegree (adjusted for redundancy): 1
# [connection from ChINs to SPNs.] Using biological parameter estimation for indegree: 1
# [connection from ChINs to SPNs.] Source population spatial dimensions: 3D
# [connection from ChINs to SPNs.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from ChINs to SPNs.] Using user-defined weight from synapse_dict
# [connection from ChINs to SPNs.] Excitatory connection: weight = +10.000
# [connection from ChINs to SPNs.] Connection dict: {'allow_autapses': False, 'rule': 'fixed_indegree', 'indegree': 1, 'allow_multapses': False, 'mask': {'spherical': {'radius': 0.5}}}
# [connection from ChINs to SPNs.] Single synapse dict: {'synapse_model': 'static_synapse_custom_connection_from_ChINs_to_SPNs.', 'weight': 10.0, 'delay': 1.0}
# [connection from ChINs to SPNs.] Connecting 150 source neurons to 8000 target neurons
# HAHA {'synapse_model': 'static_synapse_custom_connection_from_ChINs_to_SPNs.', 'weight': 10.0, 'delay': 1.0, 'receptor_type': 1}
# [connection from ChINs to SPNs.] Successfully created 8000 connections
# [connection from ChINs to SPNs.] Connection density: 0.0067
# [connection from ChINs to SPNs.] Generating Python script for connection creation...
# [connection from ChINs to SPNs.] Indegree calculation: P=1.00, Ny=150, Nx=8000, alpha=50, rho=100.00
# [connection from ChINs to SPNs.] Base formula: 1.00 * (150/8000) * 50 = 0.94
# [connection from ChINs to SPNs.] Redundancy adjustment: 0.94 / 100.00 = 1
# [connection from ChINs to SPNs.] Final indegree (adjusted for redundancy): 1
# [connection from ChINs to SPNs.] Using biological parameter estimation for indegree: 1
# [connection from ChINs to SPNs.] Source population spatial dimensions: 3D
# [connection from ChINs to SPNs.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from ChINs to SPNs.] Python script generated (46 lines)
# [connection from ChINs to SPNs.] Generating Jupyter notebook cell...
# [connection from ChINs to SPNs.] Generating Python script for connection creation...
# [connection from ChINs to SPNs.] Indegree calculation: P=1.00, Ny=150, Nx=8000, alpha=50, rho=100.00
# [connection from ChINs to SPNs.] Base formula: 1.00 * (150/8000) * 50 = 0.94
# [connection from ChINs to SPNs.] Redundancy adjustment: 0.94 / 100.00 = 1
# [connection from ChINs to SPNs.] Final indegree (adjusted for redundancy): 1
# [connection from ChINs to SPNs.] Using biological parameter estimation for indegree: 1
# [connection from ChINs to SPNs.] Source population spatial dimensions: 3D
# [connection from ChINs to SPNs.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from ChINs to SPNs.] Python script generated (46 lines)
# [connection from ChINs to SPNs.] Notebook cell generated
# Executing node: connection from SPNs to ChINs.
# [connection from SPNs to ChINs.] Validating connection parameters...
# [connection from SPNs to ChINs.] Parameter validation completed successfully
# [connection from SPNs to ChINs.] Creating custom synapse model...
# [connection from SPNs to ChINs.] Copying synapse model: static_synapse -> static_synapse_custom_connection_from_SPNs_to_ChINs.
# [connection from SPNs to ChINs.] Custom synapse model 'static_synapse_custom_connection_from_SPNs_to_ChINs.' created successfully
# [connection from SPNs to ChINs.] Creating NEST connections...
# [connection from SPNs to ChINs.] Indegree calculation: P=1.00, Ny=8000, Nx=150, alpha=50, rho=100.00
# [connection from SPNs to ChINs.] Base formula: 1.00 * (8000/150) * 50 = 2666.67
# [connection from SPNs to ChINs.] Redundancy adjustment: 2666.67 / 100.00 = 27
# [connection from SPNs to ChINs.] Final indegree (adjusted for redundancy): 27
# [connection from SPNs to ChINs.] Using biological parameter estimation for indegree: 27
# [connection from SPNs to ChINs.] Source population spatial dimensions: 3D
# [connection from SPNs to ChINs.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from SPNs to ChINs.] Using user-defined weight from synapse_dict
# [connection from SPNs to ChINs.] Inhibitory connection: weight = -4.000
# [connection from SPNs to ChINs.] Connection dict: {'allow_autapses': False, 'rule': 'fixed_indegree', 'indegree': 27, 'allow_multapses': False, 'mask': {'spherical': {'radius': 0.5}}}
# [connection from SPNs to ChINs.] Single synapse dict: {'synapse_model': 'static_synapse_custom_connection_from_SPNs_to_ChINs.', 'weight': -4.0, 'delay': 1.0}
# [connection from SPNs to ChINs.] Connecting 8000 source neurons to 150 target neurons
# HAHA {'synapse_model': 'static_synapse_custom_connection_from_SPNs_to_ChINs.', 'weight': -4.0, 'delay': 1.0, 'receptor_type': 1}
#
# Jan 30 16:27:18 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
# [connection from SPNs to ChINs.] Successfully created 4050 connections
# [connection from SPNs to ChINs.] Connection density: 0.0034
# [connection from SPNs to ChINs.] Generating Python script for connection creation...
# [connection from SPNs to ChINs.] Indegree calculation: P=1.00, Ny=8000, Nx=150, alpha=50, rho=100.00
# [connection from SPNs to ChINs.] Base formula: 1.00 * (8000/150) * 50 = 2666.67
# [connection from SPNs to ChINs.] Redundancy adjustment: 2666.67 / 100.00 = 27
# [connection from SPNs to ChINs.] Final indegree (adjusted for redundancy): 27
# [connection from SPNs to ChINs.] Using biological parameter estimation for indegree: 27
# [connection from SPNs to ChINs.] Source population spatial dimensions: 3D
# [connection from SPNs to ChINs.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from SPNs to ChINs.] Python script generated (46 lines)
# [connection from SPNs to ChINs.] Generating Jupyter notebook cell...
# [connection from SPNs to ChINs.] Generating Python script for connection creation...
# [connection from SPNs to ChINs.] Indegree calculation: P=1.00, Ny=8000, Nx=150, alpha=50, rho=100.00
# [connection from SPNs to ChINs.] Base formula: 1.00 * (8000/150) * 50 = 2666.67
# [connection from SPNs to ChINs.] Redundancy adjustment: 2666.67 / 100.00 = 27
# [connection from SPNs to ChINs.] Final indegree (adjusted for redundancy): 27
# [connection from SPNs to ChINs.] Using biological parameter estimation for indegree: 27
# [connection from SPNs to ChINs.] Source population spatial dimensions: 3D
# [connection from SPNs to ChINs.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from SPNs to ChINs.] Python script generated (46 lines)
# [connection from SPNs to ChINs.] Notebook cell generated
#
# Workflow execution completed successfully!

# %%
execution_sequence = workflow_ready.get_execution_sequence()
print(execution_sequence)
# Out:
# {'workflow_name': 'Simple population of spiking neurons', 'execution_timestamp': '2026-01-30 16:30:00', 'total_nodes': 10, 'execution_sequence': [{'node_name': 'Cholinergic Interneuron', 'node_instance': <neuroworkflow.nodes.network.SNNbuilder_SingleNeuron.SNNbuilder_SingleNeuron object at 0x76e152690650>, 'node_type': 'single_neuron_builder', 'execution_order': 0, 'timestamp': 1769758037.4017189, 'duration': 0.0011286735534667969, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties']}, {'node_name': 'ChIN_population', 'node_instance': <neuroworkflow.nodes.network.SNNbuilder_Population.SNNbuilder_Population object at 0x76e152908260>, 'node_type': 'population_builder', 'execution_order': 1, 'timestamp': 1769758037.402857, 'duration': 0.01652359962463379, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_population', 'population_data', 'python_script', 'notebook_cell']}, {'node_name': 'spike detector for ChIN pop', 'node_instance': <neuroworkflow.nodes.stimulus.SNNbuilder_Recordable.SNNbuilder_Recordable object at 0x76e15230be60>, 'node_type': 'recording_builder', 'execution_order': 2, 'timestamp': 1769758037.419388, 'duration': 0.008358478546142578, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_recorders', 'python_script', 'notebook_cell', 'recording_summary', 'target_neurons']}, {'node_name': 'direct current stimulation', 'node_instance': <neuroworkflow.nodes.stimulus.SNNbuilder_Stimulation.SNNbuilder_Stimulation object at 0x76e152309760>, 'node_type': 'stimulation_builder', 'execution_order': 3, 'timestamp': 1769758037.4277523, 'duration': 0.001764535903930664, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_stimulation_devices', 'python_script', 'notebook_cell', 'stimulation_summary', 'target_neurons']}, {'node_name': 'poisson_stimulation noise', 'node_instance': <neuroworkflow.nodes.stimulus.SNNbuilder_Stimulation.SNNbuilder_Stimulation object at 0x76e15230a480>, 'node_type': 'stimulation_builder', 'execution_order': 4, 'timestamp': 1769758037.4295213, 'duration': 0.0020678043365478516, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_stimulation_devices', 'python_script', 'notebook_cell', 'stimulation_summary', 'target_neurons']}, {'node_name': 'Spiny Projection Neuron', 'node_instance': <neuroworkflow.nodes.network.SNNbuilder_SingleNeuron.SNNbuilder_SingleNeuron object at 0x76e1522f7830>, 'node_type': 'single_neuron_builder', 'execution_order': 5, 'timestamp': 1769758037.4315932, 'duration': 0.001135110855102539, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties']}, {'node_name': 'SPN_population', 'node_instance': <neuroworkflow.nodes.network.SNNbuilder_Population.SNNbuilder_Population object at 0x76e1538cac30>, 'node_type': 'population_builder', 'execution_order': 6, 'timestamp': 1769758037.4327333, 'duration': 0.05025005340576172, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_population', 'population_data', 'python_script', 'notebook_cell']}, {'node_name': 'spike detector for SPN pop', 'node_instance': <neuroworkflow.nodes.stimulus.SNNbuilder_Recordable.SNNbuilder_Recordable object at 0x76e15230b950>, 'node_type': 'recording_builder', 'execution_order': 7, 'timestamp': 1769758037.4829898, 'duration': 0.3762171268463135, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_recorders', 'python_script', 'notebook_cell', 'recording_summary', 'target_neurons']}, {'node_name': 'connection from ChINs to SPNs.', 'node_instance': <neuro ...
