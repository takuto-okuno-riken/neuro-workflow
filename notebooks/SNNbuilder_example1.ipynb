# %% [markdown]
# ### Spiking Neural Network Builder example using NeuroWorkflow

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# import nest and reset the kernel (just in case it might be needed)
import nest
nest.ResetKernel()
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: Mar  4 2025 17:27:39
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
# Add path to NeuroWorflow
# Add the src directory to the Python path if needed
src_path = os.path.abspath(os.path.join(os.getcwd(), '../src'))
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# Import NeuroWorkflow components (custom nodes)
from neuroworkflow import WorkflowBuilder
from neuroworkflow.nodes.network.SNNbuilder_SingleNeuron import SNNbuilder_SingleNeuron
from neuroworkflow.nodes.network.SNNbuilder_Population import SNNbuilder_Population
from neuroworkflow.nodes.network.SNNbuilder_Connection import SNNbuilder_Connection
from neuroworkflow.nodes.stimulus.SNNbuilder_Stimulation import SNNbuilder_Stimulation
from neuroworkflow.nodes.stimulus.SNNbuilder_Recordable import SNNbuilder_Recordable
from neuroworkflow.nodes.simulation.SNNbuilder_Simulation import SNNbuilder_Simulation

# %% [markdown]
# ### Create a Single excitatory neuron:

# %%
# Create an instance of the node SNNbuilder_SingleNeuron
my_neuron = SNNbuilder_SingleNeuron("pyramidal neuron")
    
# Configure the neuron with biological parameters
my_neuron.configure(
    # Biological identification
    name="Pyramidal Neuron L2/3",
    acronym="PyL23",
    model_type="point_process",
    cell_class="excitatory",
        
    # Signaling properties
    neurotransmitter_types=["AMPA", "NMDA"],
    psp_amplitudes={"AMPA": 0.8, "NMDA": 0.4},
    rise_times={"AMPA": 2.0, "NMDA": 15.0},
        
    # Morphological properties
    dendrite_extent=300.0,  # μm
    dendrite_diameter=2.5,  # μm
        
    # Activity properties
    firing_rate_resting=[2.0, 8.0],    # Hz
    firing_rate_active=[15.0, 40.0],   # Hz
    firing_rate_maximum=[60.0, 120.0], # Hz
        
    # NEST model parameters
    nest_model="iaf_psc_alpha",
    nest_parameters={
        "V_th": -50.0,      # Threshold potential (mV)
        "C_m": 200.0,       # Membrane capacitance (pF)
        "tau_m": 15.0,      # Membrane time constant (ms)
        "V_reset": -70.0,   # Reset potential (mV)
        "t_ref": 2.0,        # Refractory period (ms)
        "I_e": 200.0,        #external current (pA)
    },
        
    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both"    # Python and notebook formats
    )
    
print(f"Neuron: {my_neuron._parameters['name']} ({my_neuron._parameters['acronym']})")
print(f"Neuron: {my_neuron._parameters}")
# Out:
# Neuron: Pyramidal Neuron L2/3 (PyL23)
# Neuron: {'name': 'Pyramidal Neuron L2/3', 'acronym': 'PyL23', 'model_type': 'point_process', 'cell_class': 'excitatory', 'neurotransmitter_types': ['AMPA', 'NMDA'], 'psp_amplitudes': {'AMPA': 0.8, 'NMDA': 0.4}, 'rise_times': {'AMPA': 2.0, 'NMDA': 15.0}, 'dendrite_extent': 300.0, 'dendrite_diameter': 2.5, 'firing_rate_resting': [2.0, 8.0], 'firing_rate_active': [15.0, 40.0], 'firing_rate_maximum': [60.0, 120.0], 'firing_rate_disease': [0.1, 2.0], 'nest_model': 'iaf_psc_alpha', 'nest_parameters': {'V_th': -50.0, 'C_m': 200.0, 'tau_m': 15.0, 'V_reset': -70.0, 't_ref': 2.0, 'I_e': 200.0}, 'template_suffix': '_custom', 'execution_mode': 'both', 'script_format': 'both'}

# %%
#my_neuron.get_info() #uncomment to check the info of a node

# %%
my_neuron._parameters
# Out:
# {'name': 'Pyramidal Neuron L2/3',
#  'acronym': 'PyL23',
#  'model_type': 'point_process',
#  'cell_class': 'excitatory',
#  'neurotransmitter_types': ['AMPA', 'NMDA'],
#  'psp_amplitudes': {'AMPA': 0.8, 'NMDA': 0.4},
#  'rise_times': {'AMPA': 2.0, 'NMDA': 15.0},
#  'dendrite_extent': 300.0,
#  'dendrite_diameter': 2.5,
#  'firing_rate_resting': [2.0, 8.0],
#  'firing_rate_active': [15.0, 40.0],
#  'firing_rate_maximum': [60.0, 120.0],
#  'firing_rate_disease': [0.1, 2.0],
#  'nest_model': 'iaf_psc_alpha',
#  'nest_parameters': {'V_th': -50.0,
#   'C_m': 200.0,
#   'tau_m': 15.0,
#   'V_reset': -70.0,
#   't_ref': 2.0,
#   'I_e': 200.0},
#  'template_suffix': '_custom',
#  'execution_mode': 'both',
#  'script_format': 'both'}

# %% [markdown]
# ### Create a population of exitatory neurons (using the previous neuron model):

# %%
# Create a population 
my_pop = SNNbuilder_Population('cortical_population')
    
# Configure the population parameters
my_pop.configure(
    name='Layer 2/3 Pyramidal Neurons',
    acronym='L23Pyr',
    brain_region='Primary Visual Cortex',
    population_size= 800,
    tissue_reference={ #this is a free format dictionary
        'density_per_mm3': 25000,
        'tissue_volume_mm3': 0.2,
        'reference_study': 'Schüz & Palm (1989)',
        'species': 'human',
        'estimation_method': 'stereological counting'
    },
    spatial_dimensions='3D',
    spatial_bounds={
        'x': (0.0, 2.0),
        'y': (0.0, 2.0),
        'z': (0.0, 1.0)
    },
    model_type='point_process',
    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both"    # Python and notebook formats
    )
print(f"Population: {my_pop._parameters}")
# Out:
# Population: {'name': 'Layer 2/3 Pyramidal Neurons', 'acronym': 'L23Pyr', 'brain_region': 'Primary Visual Cortex', 'model_type': 'point_process', 'population_size': 800, 'tissue_reference': {'density_per_mm3': 25000, 'tissue_volume_mm3': 0.2, 'reference_study': 'Schüz & Palm (1989)', 'species': 'human', 'estimation_method': 'stereological counting'}, 'spatial_dimensions': '3D', 'spatial_bounds': {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)}, 'custom_positions': None, 'mean_firing_rate': None, 'execution_mode': 'both', 'script_format': 'both'}

# %%
my_pop._parameters
# Out:
# {'name': 'Layer 2/3 Pyramidal Neurons',
#  'acronym': 'L23Pyr',
#  'brain_region': 'Primary Visual Cortex',
#  'model_type': 'point_process',
#  'population_size': 800,
#  'tissue_reference': {'density_per_mm3': 25000,
#   'tissue_volume_mm3': 0.2,
#   'reference_study': 'Schüz & Palm (1989)',
#   'species': 'human',
#   'estimation_method': 'stereological counting'},
#  'spatial_dimensions': '3D',
#  'spatial_bounds': {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)},
#  'custom_positions': None,
#  'mean_firing_rate': None,
#  'execution_mode': 'both',
#  'script_format': 'both'}

# %% [markdown]
# ### Create a Single inhibitory neuron:

# %%
my_neuron_inh = SNNbuilder_SingleNeuron("Parvalbumin-expressing interneuron")
    
# Configure the neuron with biological parameters
my_neuron_inh.configure(
    # Biological identification
    name="PV interneuron",
    acronym="PV",
    model_type="point_process",
    cell_class="inhibitory",
        
    # NEST model parameters
    nest_model="iaf_psc_alpha",
    nest_parameters={
        "C_m": 200.0,       # Membrane capacitance (pF)
    },
        
    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both"    # Python and notebook formats
    )
    
print(f"Neuron: {my_neuron_inh._parameters['name']} ({my_neuron_inh._parameters['acronym']})")
print(f"Neuron: {my_neuron_inh._parameters}")
# Out:
# Neuron: PV interneuron (PV)
# Neuron: {'name': 'PV interneuron', 'acronym': 'PV', 'model_type': 'point_process', 'cell_class': 'inhibitory', 'neurotransmitter_types': ['AMPA', 'NMDA'], 'psp_amplitudes': {'AMPA': 0.5, 'NMDA': 0.3}, 'rise_times': {'AMPA': 2.0, 'NMDA': 10.0}, 'dendrite_extent': 200.0, 'dendrite_diameter': 2.0, 'firing_rate_resting': [1.0, 5.0], 'firing_rate_active': [10.0, 30.0], 'firing_rate_maximum': [50.0, 100.0], 'firing_rate_disease': [0.1, 2.0], 'nest_model': 'iaf_psc_alpha', 'nest_parameters': {'C_m': 200.0}, 'template_suffix': '_custom', 'execution_mode': 'both', 'script_format': 'both'}

# %% [markdown]
# ### Create a population of inhibitory neurons (using the previous neuron model):

# %%
# Create a population 
my_pop_inh = SNNbuilder_Population('inhibitory cortical population')
    
# Configure the population parameters
my_pop_inh.configure(
    name='Layer of PV neurons',
    acronym='PVpop',
    brain_region='Primary Visual Cortex',
    population_size= 100,
    spatial_dimensions='3D',
    spatial_bounds={
        'x': (0.0, 2.0),
        'y': (0.0, 2.0),
        'z': (0.0, 1.0)
    },
    model_type='point_process',
    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both"    # Python and notebook formats
    )
print(f"Population: {my_pop_inh._parameters}")
# Out:
# Population: {'name': 'Layer of PV neurons', 'acronym': 'PVpop', 'brain_region': 'Primary Visual Cortex', 'model_type': 'point_process', 'population_size': 100, 'tissue_reference': {}, 'spatial_dimensions': '3D', 'spatial_bounds': {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)}, 'custom_positions': None, 'mean_firing_rate': None, 'execution_mode': 'both', 'script_format': 'both'}

# %%
my_pop_inh._parameters
# Out:
# {'name': 'Layer of PV neurons',
#  'acronym': 'PVpop',
#  'brain_region': 'Primary Visual Cortex',
#  'model_type': 'point_process',
#  'population_size': 100,
#  'tissue_reference': {},
#  'spatial_dimensions': '3D',
#  'spatial_bounds': {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)},
#  'custom_positions': None,
#  'mean_firing_rate': None,
#  'execution_mode': 'both',
#  'script_format': 'both'}

# %% [markdown]
# ### Create a workflow instance and add the created nodes

# %%
# Create a workflow builder
workflow = WorkflowBuilder("Simple population of spiking neurons")

# Add nodes to the workflow
workflow.add_node(my_neuron)
workflow.add_node(my_neuron_inh)
workflow.add_node(my_pop)
workflow.add_node(my_pop_inh)

# %%
# Get port names from any node instance

my_neuron_output_ports = list(my_neuron.get_info()['output_ports'].keys())  
print(f"Neuron output ports: {my_neuron_output_ports}")

print(f"Population input ports: {my_pop.get_info()['input_ports'].keys()}")
# Out:
# Neuron output ports: ['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties']
# Population input ports: dict_keys(['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties'])

# %% [markdown]
# ### Connect the nodes by input and output ports (source node name, output port, target node name, input port)

# %%
# Connect the nodes by ports

workflow.connect(
    my_neuron.name, my_neuron_output_ports[1], 
    my_pop.name, "nest_model_name"
)
workflow.connect(
    my_neuron.name, my_neuron_output_ports[-2], 
    my_pop.name, "biological_properties"
)
workflow.connect(
    my_neuron_inh.name, 'nest_model_name', 
    my_pop_inh.name, "nest_model_name"
)
workflow.connect(
    my_neuron_inh.name, 'biological_properties', 
    my_pop_inh.name, "biological_properties"
)

# %%
# count the connection number in the workflow
workflow.get_connection_count()
# Out:
# 4

# %% [markdown]
# ### Connect Exc.to Inh populations using NEST connection rules

# %%
# Create a connection
EI_connect = SNNbuilder_Connection('connection from Exc. to Inh Neurons.')
    
# Configure the connection rule parameters

EI_connect.configure(
    name='EI indegree',
    connection_rule='fixed_indegree',
    connection_dict={'allow_autapses': False}, 
    synapse_model= 'static_synapse',
    synapse_dict= {'weight': 4.0, 'delay': 1.0},

    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both",    # Python and notebook formats

    redundancy=100.0 #to adjust the indegree
    )
print(f"Rule: {EI_connect._parameters}")
# Out:
# Rule: {'name': 'EI indegree', 'connection_rule': 'fixed_indegree', 'connection_dict': {'allow_autapses': False}, 'synapse_model': 'static_synapse', 'synapse_dict': {'weight': 4.0, 'delay': 1.0}, 'template_suffix': '_custom', 'axon_organization': 'focused', 'axon_radius': 0.5, 'mask_type': 'circular', 'projection_percentage': 100.0, 'bouton_number': 50, 'receptor_location': None, 'redundancy': 100.0, 'execution_mode': 'both', 'script_format': 'both'}

# %%
#EI_connect.get_info()

# %% [markdown]
# ### Connect Inh.to Exc populations using NEST connection rules

# %%
# Create a population 
IE_connect = SNNbuilder_Connection('connection from Inh to Exc Neurons')
    
# Configure the connection rule parameters

IE_connect.configure(
    name='IE indegree',
    connection_rule='fixed_indegree',
    connection_dict={'allow_autapses': False}, 
    synapse_model= 'static_synapse',
    synapse_dict= {'weight': 10.0, 'delay': 1.0},

    # Execution options
    execution_mode="both",  # Execute and generate script
    script_format="both",    # Python and notebook formats

    redundancy=50.0, #to adjust the indegree
    axon_radius= 1.0
    )
print(f"Rule: {IE_connect._parameters}")
# Out:
# Rule: {'name': 'IE indegree', 'connection_rule': 'fixed_indegree', 'connection_dict': {'allow_autapses': False}, 'synapse_model': 'static_synapse', 'synapse_dict': {'weight': 10.0, 'delay': 1.0}, 'template_suffix': '_custom', 'axon_organization': 'focused', 'axon_radius': 1.0, 'mask_type': 'circular', 'projection_percentage': 100.0, 'bouton_number': 50, 'receptor_location': None, 'redundancy': 50.0, 'execution_mode': 'both', 'script_format': 'both'}

# %% [markdown]
# ### Add the connection nodes to the workflow

# %%
workflow.add_node(EI_connect)
workflow.add_node(IE_connect)

# %% [markdown]
# ### Check available ports

# %%
my_pop.get_info()['output_ports'], EI_connect.get_info()['input_ports']
# Out:
# ({'nest_population': {'type': 'object',
#    'description': 'NEST population object (if execution mode)'},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata and configuration'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python code for population creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell code for population creation'}},
#  {'source_nest_population': {'type': 'object',
#    'description': 'Source NEST population object',
#    'optional': True},
#   'source_population_metadata': {'type': 'dict',
#    'description': 'Source population metadata and properties',
#    'optional': True},
#   'source_neuron_properties': {'type': 'dict',
#    'description': 'Source neuron biological properties (including PSP data)',
#    'optional': True},
#   'target_nest_population': {'type': 'object',
#    'description': 'Target NEST population object',
#    'optional': True},
#   'target_population_metadata': {'type': 'dict',
#    'description': 'Target population metadata and properties',
#    'optional': True},
#   'target_neuron_properties': {'type': 'dict',
#    'description': 'Target neuron biological properties',
#    'optional': True},
#   'connection_parameter_overrides': {'type': 'dict',
#    'description': 'Dictionary of connection parameter overrides',
#    'optional': True}})

# %% [markdown]
# ### Connect Population nodes with Connection rule nodes (E->I, I->E)

# %%
workflow.connect( 
    my_pop.name, "nest_population",
    EI_connect.name, "source_nest_population")
workflow.connect( 
    my_pop.name, "population_data",
    EI_connect.name, "source_population_metadata")

workflow.connect( 
    my_pop_inh.name, "nest_population",
    EI_connect.name, "target_nest_population")
workflow.connect( 
    my_pop_inh.name, "population_data",
    EI_connect.name, "target_population_metadata")

# %%
workflow.connect( 
    my_pop_inh.name, "nest_population",
    IE_connect.name, "source_nest_population")
workflow.connect( 
    my_pop_inh.name, "population_data",
    IE_connect.name, "source_population_metadata")

workflow.connect( 
    my_pop.name, "nest_population",
    IE_connect.name, "target_nest_population")
workflow.connect( 
    my_pop.name, "population_data",
    IE_connect.name, "target_population_metadata")

# %%
workflow.get_connection_count()
# Out:
# 12

# %% [markdown]
# ### Create stimulation nodes (poisson generator and DC generator)

# %%
#Create a stimulus
stim_pg = SNNbuilder_Stimulation("poisson_stimulation noise")

# %%
# defaul parameters
#stim_pg._parameters

# %%
# Define parameters
stim_pg.configure(
    # Stimulation type and devices
    stimulation_type= 'poisson_generator',
    number_of_devices= 1,
        
    # Poisson generator parameters
    poisson_parameters= {
        'rate': 50.0,      # Hz
        'start': 100.0,    # ms
        'stop': 900.0      # ms
    },
        
    # Target all neurons in population
    target_identification= 'full_population',
        
    # Synapse specification
    synapse_specification= {
            'synapse_model': 'static_synapse',
            'weight': 2.5,     # pA
            'delay': 1.5       # ms
        },
        
        # Template and execution options
        template_suffix= '_custom',
        script_format= 'both',        # Generate both script and notebook
        execution_mode= 'both' #  Execute and generate script
    )

print(f"Stimulus: {stim_pg._parameters}")
# Out:
# Stimulus: {'stimulation_type': 'poisson_generator', 'number_of_devices': 1, 'poisson_parameters': {'rate': 50.0, 'start': 100.0, 'stop': 900.0}, 'dc_parameters': {'label': 'dc_stim', 'start': 0.0, 'stop': 1000.0, 'amplitude': 100.0}, 'synapse_specification': {'synapse_model': 'static_synapse', 'weight': 2.5, 'delay': 1.5}, 'target_identification': 'full_population', 'volume_area_specification': {'center_coordinates': [0.0, 0.0, 0.0], 'radius': 0.5}, 'execution_mode': 'both', 'script_format': 'both', 'template_suffix': '_custom'}

# %%
#Create a stimulus
stim_dc = SNNbuilder_Stimulation("direct current stimulation")

stim_dc.configure(
    # Stimulation type and devices
    stimulation_type= 'dc_generator',
    number_of_devices= 1, #always 1 for DC generator

    #dc parameters
    dc_parameters= {
        'label': 'dc_stim',
        'start': 500.0,
        'stop': 700.0,
        'amplitude': 100.0
    },
        
    # Target all neurons in population
    target_identification= 'define_volume_area',
    volume_area_specification= {
        'center_coordinates': [0.0, 0.0, 0.0],
        'radius': 0.5
    },

    script_format= 'both',        # Generate both script and notebook
    execution_mode= 'both' #  Execute and generate script
)

print(f"Stimulus: {stim_dc._parameters}")
# Out:
# Stimulus: {'stimulation_type': 'dc_generator', 'number_of_devices': 1, 'poisson_parameters': {'label': 'poisson_stim', 'start': 0.0, 'stop': 1000.0, 'rate': 100.0}, 'dc_parameters': {'label': 'dc_stim', 'start': 500.0, 'stop': 700.0, 'amplitude': 100.0}, 'synapse_specification': {'synapse_model': 'static_synapse', 'weight': 1.0, 'delay': 1.0}, 'target_identification': 'define_volume_area', 'volume_area_specification': {'center_coordinates': [0.0, 0.0, 0.0], 'radius': 0.5}, 'execution_mode': 'both', 'script_format': 'both', 'template_suffix': '_custom'}

# %% [markdown]
# ### Add stimulation nodes to the workflow

# %%
workflow.add_node(stim_pg)
workflow.add_node(stim_dc)

# %%
my_pop.get_info()['output_ports'], stim_pg.get_info()['input_ports']
# Out:
# ({'nest_population': {'type': 'object',
#    'description': 'NEST population object (if execution mode)'},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata and configuration'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python code for population creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell code for population creation'}},
#  {'nest_population': {'type': 'object',
#    'description': 'NEST population object to stimulate',
#    'optional': False},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata including spatial information',
#    'optional': False}})

# %% [markdown]
# ### Connect stimulation nodes to population nodes

# %%
workflow.connect( 
    my_pop.name, "nest_population",
    stim_pg.name, "nest_population")
workflow.connect( 
    my_pop.name, "population_data",
    stim_pg.name, "population_data")

workflow.connect( 
    my_pop.name, "nest_population",
    stim_dc.name, "nest_population")
workflow.connect( 
    my_pop.name, "population_data",
    stim_dc.name, "population_data")

# %%
workflow.get_connection_count()
# Out:
# 16

# %% [markdown]
# ### Create recordable nodes (spike recorder)

# %%
#Create a recordable for exc. population
sp_exc = SNNbuilder_Recordable("spike detector for Exc. pop")

sp_exc.configure(
    # recording type and devices
    recording_type= 'spike_recorder',

    #spike_recorder parameters
    spike_recorder_parameters= {
        'record_to': 'ascii',
        'start': 0.0,
        'stop': 1000.0,
    },
        
    # Target all neurons in population
    target_identification= 'full_population',

    script_format= 'both',        # Generate both script and notebook
    execution_mode= 'both' #  Execute and generate script
)

print(f"Stimulus: {sp_exc._parameters}")
# Out:
# Stimulus: {'recording_type': 'spike_recorder', 'number_of_devices': 1, 'spike_recorder_parameters': {'record_to': 'ascii', 'start': 0.0, 'stop': 1000.0}, 'target_identification': 'full_population', 'volume_area_specification': {'center_coordinates': [0.0, 0.0, 0.0], 'radius': 0.5}, 'script_format': 'both', 'execution_mode': 'both'}

# %%
#Create an other recordable
sp_inh = SNNbuilder_Recordable("spike detector for some neurons at Inh. pop")

sp_inh.configure(
    # recording type and devices
    recording_type= 'spike_recorder',

    #spike_recorder parameters
    spike_recorder_parameters= {
        'record_to': 'ascii',
        'start': 0.0,
        'stop': 1000.0,
    },
        
    # Target all neurons in population
    target_identification= 'define_volume_area',
    
    volume_area_specification= {
        'center_coordinates': [0.0, 0.0, 0.0],
        'radius': 0.5
    },

    script_format= 'both',        # Generate both script and notebook
    execution_mode= 'both' #  Execute and generate script
)

print(f"Stimulus: {sp_inh._parameters}")
# Out:
# Stimulus: {'recording_type': 'spike_recorder', 'number_of_devices': 1, 'spike_recorder_parameters': {'record_to': 'ascii', 'start': 0.0, 'stop': 1000.0}, 'target_identification': 'define_volume_area', 'volume_area_specification': {'center_coordinates': [0.0, 0.0, 0.0], 'radius': 0.5}, 'script_format': 'both', 'execution_mode': 'both'}

# %%
my_pop.get_info()['output_ports'], sp_exc.get_info()['input_ports']
# Out:
# ({'nest_population': {'type': 'object',
#    'description': 'NEST population object (if execution mode)'},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata and configuration'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python code for population creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell code for population creation'}},
#  {'nest_population': {'type': 'object',
#    'description': 'NEST population object to record from',
#    'optional': False},
#   'population_data': {'type': 'dict',
#    'description': 'Population metadata including spatial information',
#    'optional': False}})

# %% [markdown]
# ### Add recordable nodes to the workflow

# %%
workflow.add_node(sp_exc)
workflow.add_node(sp_inh)

# %% [markdown]
# ### Connect population nodes to recordable nodes

# %%
workflow.connect( 
    my_pop.name, "nest_population",
    sp_exc.name, "nest_population")
workflow.connect( 
    my_pop.name, "population_data",
    sp_exc.name, "population_data")

workflow.connect( 
    my_pop.name, "nest_population",
    sp_inh.name, "nest_population")
workflow.connect( 
    my_pop.name, "population_data",
    sp_inh.name, "population_data")

# %%
workflow.get_connection_count()
# Out:
# 20

# %% [markdown]
# ### Build the workflow

# %%
# Build the workflow
workflow_ready = workflow.build()

# Print workflow information
print(workflow_ready)
# Out:
# Workflow: Simple population of spiking neurons
# Nodes:
#   pyramidal neuron
#   Parvalbumin-expressing interneuron
#   cortical_population
#   inhibitory cortical population
#   connection from Exc. to Inh Neurons.
#   connection from Inh to Exc Neurons
#   poisson_stimulation noise
#   direct current stimulation
#   spike detector for Exc. pop
#   spike detector for some neurons at Inh. pop
# Connections:
#   pyramidal neuron.nest_model_name -> cortical_population.nest_model_name
#   pyramidal neuron.biological_properties -> cortical_population.biological_properties
#   Parvalbumin-expressing interneuron.nest_model_name -> inhibitory cortical population.nest_model_name
#   Parvalbumin-expressing interneuron.biological_properties -> inhibitory cortical population.biological_properties
#   cortical_population.nest_population -> connection from Exc. to Inh Neurons..source_nest_population
#   cortical_population.population_data -> connection from Exc. to Inh Neurons..source_population_metadata
#   inhibitory cortical population.nest_population -> connection from Exc. to Inh Neurons..target_nest_population
#   inhibitory cortical population.population_data -> connection from Exc. to Inh Neurons..target_population_metadata
#   inhibitory cortical population.nest_population -> connection from Inh to Exc Neurons.source_nest_population
#   inhibitory cortical population.population_data -> connection from Inh to Exc Neurons.source_population_metadata
#   cortical_population.nest_population -> connection from Inh to Exc Neurons.target_nest_population
#   cortical_population.population_data -> connection from Inh to Exc Neurons.target_population_metadata
#   cortical_population.nest_population -> poisson_stimulation noise.nest_population
#   cortical_population.population_data -> poisson_stimulation noise.population_data
#   cortical_population.nest_population -> direct current stimulation.nest_population
#   cortical_population.population_data -> direct current stimulation.population_data
#   cortical_population.nest_population -> spike detector for Exc. pop.nest_population
#   cortical_population.population_data -> spike detector for Exc. pop.population_data
#   cortical_population.nest_population -> spike detector for some neurons at Inh. pop.nest_population
#   cortical_population.population_data -> spike detector for some neurons at Inh. pop.population_data

# %% [markdown]
# ### Workflow Execution

# %%
# Execute the workflow
print("Executing workflow...")
success = workflow_ready.execute()

if success:
    print("\nWorkflow execution completed successfully!")
else:
    print("\nWorkflow execution failed!")
# Out:
# Executing workflow...
# Executing node: Parvalbumin-expressing interneuron
# [Parvalbumin-expressing interneuron] Validating neuron parameters...
# [Parvalbumin-expressing interneuron] Parameter validation completed successfully
# [Parvalbumin-expressing interneuron] Creating NEST neuron...
# [Parvalbumin-expressing interneuron] Copying model: iaf_psc_alpha -> iaf_psc_alpha_PV_custom
# [Parvalbumin-expressing interneuron] Applied inhibitory cell class defaults: {'V_th': -52.0, 'V_reset': -65.0, 'tau_m': 10.0, 't_ref': 1.0}
# [Parvalbumin-expressing interneuron] Setting defaults: {'C_m': 200.0, 'V_th': -52.0, 'V_reset': -65.0, 'tau_m': 10.0, 't_ref': 1.0}
# [Parvalbumin-expressing interneuron] Creating neuron from template: iaf_psc_alpha_PV_custom
# [Parvalbumin-expressing interneuron] NEST neuron created successfully: NodeCollection(metadata=None, model=iaf_psc_alpha_PV_custom, size=1, first=1)
# [Parvalbumin-expressing interneuron] Generating Python script...
# [Parvalbumin-expressing interneuron] Python script generated (30 lines)
# [Parvalbumin-expressing interneuron] Generating Jupyter notebook cell...
# [Parvalbumin-expressing interneuron] Generating Python script...
# [Parvalbumin-expressing interneuron] Python script generated (30 lines)
# [Parvalbumin-expressing interneuron] Notebook cell generated
# [Parvalbumin-expressing interneuron] Compiling neuron metadata...
# [Parvalbumin-expressing interneuron] Metadata compilation completed
# Executing node: inhibitory cortical population
# [inhibitory cortical population] Validating population parameters...
# [inhibitory cortical population] Generated random 3D positions for 100 neurons
# [inhibitory cortical population] Parameter validation completed successfully
# [inhibitory cortical population] Creating NEST population...
# [inhibitory cortical population] Creating 100 neurons of type 'iaf_psc_alpha_PV_custom'
# [inhibitory cortical population] Create NEST population with generated positions from helper method
# [inhibitory cortical population] Population created with 3D spatial positions
# [inhibitory cortical population] Status of first neuron: ({'archiver_length': 0, 'beta_Ca': 0.001, 'C_m': 200.0, 'Ca': 0.0, 'E_L': -70.0, 'element_type': 'neuron', 'frozen': False, 'global_id': 2, 'I_e': 0.0, 'local': True, 'model': 'iaf_psc_alpha_PV_custom', 'model_id': 99, 'node_uses_wfr': False, 'post_trace': 0.0, 'recordables': ('I_syn_ex', 'I_syn_in', 'V_m'), 'synaptic_elements': {}, 't_ref': 1.0, 't_spike': -1.0, 'tau_Ca': 10000.0, 'tau_m': 10.0, 'tau_minus': 20.0, 'tau_minus_triplet': 110.0, 'tau_syn_ex': 2.0, 'tau_syn_in': 2.0, 'thread': 0, 'thread_local_id': -1, 'V_m': -70.0, 'V_min': -inf, 'V_reset': -65.0, 'V_th': -52.0, 'vp': 0},)
# [inhibitory cortical population] NEST population created successfully: NodeCollection(metadata=spatial, model=iaf_psc_alpha_PV_custom, size=100, first=2, last=101)
# [inhibitory cortical population] Generating Python script...
# [inhibitory cortical population] Python script generated (37 lines)
# [inhibitory cortical population] Generating Jupyter notebook cell...
# [inhibitory cortical population] Notebook cell generated (9 lines)
# Executing node: pyramidal neuron
# [pyramidal neuron] Validating neuron parameters...
# [pyramidal neuron] Parameter validation completed successfully
# [pyramidal neuron] Creating NEST neuron...
# [pyramidal neuron] Copying model: iaf_psc_alpha -> iaf_psc_alpha_PyL23_custom
# [pyramidal neuron] Setting defaults: {'V_th': -50.0, 'C_m': 200.0, 'tau_m': 15.0, 'V_reset': -70.0, 't_ref': 2.0, 'I_e': 200.0}
# [pyramidal neuron] Creating neuron from template: iaf_psc_alpha_PyL23_custom
# [pyramidal neuron] NEST neuron created successfully: NodeCollection(metadata=None, model=iaf_psc_alpha_PyL23_custom, size=1, first=102)
# [pyramidal neuron] Generating Python script...
# [pyramidal neuron] Python script generated (24 lines)
# [pyramidal neuron] Generating Jupyter notebook cell...
# [pyramidal neuron] Generating Python script...
# [pyramidal neuron] Python script generated (24 lines)
# [pyramidal neuron] Notebook cell generated
# [pyramidal neuron] Compiling neuron metadata...
# [pyramidal neuron] Metadata compilation completed
# Executing node: cortical_population
# [cortical_population] Validating population parameters...
# [cortical_population] Generated random 3D positions for 800 neurons
# [cortical_population] Parameter validation completed successfully
# [cortical_population] Creating NEST population...
# [cortical_population] Creating 800 neurons of type 'iaf_psc_alpha_PyL23_custom'
# [cortical_population] Create NEST population with generated positions from helper method
# [cortical_population] Population created with 3D spatial positions
# [cortical_population] Status of first neuron: ({'archiver_length': 0, 'beta_Ca': 0.001, 'C_m': 200.0, 'Ca': 0.0, 'E_L': -70.0, 'element_type': 'neuron', 'frozen': False, 'global_id': 103, 'I_e': 200.0, 'local': True, 'model': 'iaf_psc_alpha_PyL23_custom', 'model_id': 100, 'node_uses_wfr': False, 'post_trace': 0.0, 'recordables': ('I_syn_ex', 'I_syn_in', 'V_m'), 'synaptic_elements': {}, 't_ref': 2.0, 't_spike': -1.0, 'tau_Ca': 10000.0, 'tau_m': 15.0, 'tau_minus': 20.0, 'tau_minus_triplet': 110.0, 'tau_syn_ex': 2.0, 'tau_syn_in': 2.0, 'thread': 0, 'thread_local_id': -1, 'V_m': -70.0, 'V_min': -inf, 'V_reset': -70.0, 'V_th': -50.0, 'vp': 0},)
# [cortical_population] NEST population created successfully: NodeCollection(metadata=spatial, model=iaf_psc_alpha_PyL23_custom, size=800, first=103, last=902)
# [cortical_population] Generating Python script...
# [cortical_population] Python script generated (42 lines)
# [cortical_population] Generating Jupyter notebook cell...
# [cortical_population] Notebook cell generated (9 lines)
# Executing node: spike detector for some neurons at Inh. pop
# [spike detector for some neurons at Inh. pop] Validating recording parameters...
# [spike detector for some neurons at Inh. pop] Parameter validation completed successfully
# [spike detector for some neurons at Inh. pop] Creating recording devices...
# [spike detector for some neurons at Inh. pop] Created 1 spike_recorder device(s)
# [spike detector for some neurons at Inh. pop] Skipping target identification (execution_mode: both)
# [spike detector for some neurons at Inh. pop] Creating connections...
# [spike detector for some neurons at Inh. pop] Connected 11 neurons to 1 recording device(s)
# [spike detector for some neurons at Inh. pop] Total connections: 11
# [spike detector for some neurons at Inh. pop] Generating Python script...
# [spike detector for some neurons at Inh. pop] Python script generated (44 lines)
# [spike detector for some neurons at Inh. pop] Generating Python script...
# [spike detector for some neurons at Inh. pop] Python script generated (44 lines)
# Warning: Expected output 'recording_summary' not produced by process step 'compile_summary' (method: compile_summary)
# Executing node: spike detector for Exc. pop
# [spike detector for Exc. pop] Validating recording parameters...
# [spike detector for Exc. pop] Parameter validation completed successfully
# [spike detector for Exc. pop] Creating recording devices...
# [spike detector for Exc. pop] Created 1 spike_recorder device(s)
# [spike detector for Exc. pop] Skipping target identification (execution_mode: both)
# [spike detector for Exc. pop] Creating connections...
# [spike detector for Exc. pop] Connected 800 neurons to 1 recording device(s)
# [spike detector for Exc. pop] Total connections: 800
# [spike detector for Exc. pop] Generating Python script...
# [spike detector for Exc. pop] Python script generated (28 lines)
# [spike detector for Exc. pop] Generating Python script...
# [spike detector for Exc. pop] Python script generated (28 lines)
# Warning: Expected output 'recording_summary' not produced by process step 'compile_summary' (method: compile_summary)
# Executing node: direct current stimulation
# [direct current stimulation] Validating stimulation parameters...
# [direct current stimulation] Parameter validation completed successfully
# [direct current stimulation] Creating stimulation devices...
# [direct current stimulation] Custom synapse model 'static_synapse_custom_direct_current_stimulation' created successfully
# [direct current stimulation] Created 1 dc_generator device(s)
# [direct current stimulation] Successfully created 1 stimulation device(s)
# [direct current stimulation] Identifying target neurons...
# [direct current stimulation] Targeting volume area (11 neurons)
# [direct current stimulation] Creating connections...
# [direct current stimulation] Connected DC generator to 11 target neurons (direct current injection)
# [direct current stimulation] Successfully created 11 connections
# [direct current stimulation] Generating Python script...
# [direct current stimulation] Python script generated (44 lines)
# [direct current stimulation] Generating Jupyter notebook cell...
# [direct current stimulation] Generating Python script...
# [direct current stimulation] Python script generated (44 lines)
# [direct current stimulation] Notebook cell generated
# [direct current stimulation] Compiling stimulation summary...
# [direct current stimulation] Stimulation summary compiled
# Executing node: poisson_stimulation noise
# [poisson_stimulation noise] Validating stimulation parameters...
# [poisson_stimulation noise] Parameter validation completed successfully
# [poisson_stimulation noise] Creating stimulation devices...
# [poisson_stimulation noise] Custom synapse model 'static_synapse_custom_poisson_stimulation_noise' created successfully
# [poisson_stimulation noise] Created 1 poisson_generator device(s)
# [poisson_stimulation noise] Successfully created 1 stimulation device(s)
# [poisson_stimulation noise] Identifying target neurons...
# [poisson_stimulation noise] Targeting full population (800 neurons)
# [poisson_stimulation noise] Creating connections...
# [poisson_stimulation noise] Connected 1 Poisson device to 800 target neurons
# [poisson_stimulation noise] Successfully created 800 connections
# [poisson_stimulation noise] Generating Python script...
# [poisson_stimulation noise] Python script generated (41 lines)
# [poisson_stimulation noise] Generating Jupyter notebook cell...
# [poisson_stimulation noise] Generating Python script...
# [poisson_stimulation noise] Python script generated (41 lines)
# [poisson_stimulation noise] Notebook cell generated
# [poisson_stimulation noise] Compiling stimulation summary...
# [poisson_stimulation noise] Stimulation summary compiled
# Executing node: connection from Inh to Exc Neurons
# [connection from Inh to Exc Neurons] Validating connection parameters...
# [connection from Inh to Exc Neurons] Parameter validation completed successfully
# [connection from Inh to Exc Neurons] Creating custom synapse model...
# [connection from Inh to Exc Neurons] Copying synapse model: static_synapse -> static_synapse_custom_connection_from_Inh_to_Exc_Neurons
# [connection from Inh to Exc Neurons] Custom synapse model 'static_synapse_custom_connection_from_Inh_to_Exc_Neurons' created successfully
# [connection from Inh to Exc Neurons] Creating NEST connections...
# [connection from Inh to Exc Neurons] Indegree calculation: P=1.00, Ny=100, Nx=800, alpha=50, rho=50.00
# [connection from Inh to Exc Neurons] Base formula: 1.00 * (100/800) * 50 = 6.25
# [connection from Inh to Exc Neurons] Redundancy adjustment: 6.25 / 50.00 = 1
# [connection from Inh to Exc Neurons] Final indegree (adjusted for redundancy): 1
# [connection from Inh to Exc Neurons] Using biological parameter estimation for indegree: 1
# [connection from Inh to Exc Neurons] Source population spatial dimensions: 3D
# [connection from Inh to Exc Neurons] Created spherical mask with radius 1.0 based on axon_radius
# [connection from Inh to Exc Neurons] Using user-defined weight from synapse_dict
# [connection from Inh to Exc Neurons] Inhibitory connection: weight = -10.000
# [connection from Inh to Exc Neurons] Connection dict: {'allow_autapses': False, 'rule': 'fixed_indegree', 'indegree': 1, 'allow_multapses': False, 'mask': {'spherical': {'radius': 1.0}}}
# [connection from Inh to Exc Neurons] Single synapse dict: {'synapse_model': 'static_synapse_custom_connection_from_Inh_to_Exc_Neurons', 'weight': -10.0, 'delay': 1.0}
# [connection from Inh to Exc Neurons] Connecting 100 source neurons to 800 target neurons
#
# Sep 27 23:44:27 ConnectionManager [Warning]:
# [connection from Inh to Exc Neurons] Successfully created 800 connections
# [connection from Inh to Exc Neurons] Connection density: 0.0100
# [connection from Inh to Exc Neurons] Generating Python script for connection creation...
# [connection from Inh to Exc Neurons] Indegree calculation: P=1.00, Ny=100, Nx=800, alpha=50, rho=50.00
# [connection from Inh to Exc Neurons] Base formula: 1.00 * (100/800) * 50 = 6.25
# [connection from Inh to Exc Neurons] Redundancy adjustment: 6.25 / 50.00 = 1
# [connection from Inh to Exc Neurons] Final indegree (adjusted for redundancy): 1
# [connection from Inh to Exc Neurons] Using biological parameter estimation for indegree: 1
# [connection from Inh to Exc Neurons] Source population spatial dimensions: 3D
# [connection from Inh to Exc Neurons] Created spherical mask with radius 1.0 based on axon_radius
# [connection from Inh to Exc Neurons] Python script generated (46 lines)
# [connection from Inh to Exc Neurons] Generating Jupyter notebook cell...
# [connection from Inh to Exc Neurons] Generating Python script for connection creation...
# [connection from Inh to Exc Neurons] Indegree calculation: P=1.00, Ny=100, Nx=800, alpha=50, rho=50.00
# [connection from Inh to Exc Neurons] Base formula: 1.00 * (100/800) * 50 = 6.25
# [connection from Inh to Exc Neurons] Redundancy adjustment: 6.25 / 50.00 = 1
# [connection from Inh to Exc Neurons] Final indegree (adjusted for redundancy): 1
# [connection from Inh to Exc Neurons] Using biological parameter estimation for indegree: 1
# [connection from Inh to Exc Neurons] Source population spatial dimensions: 3D
# [connection from Inh to Exc Neurons] Created spherical mask with radius 1.0 based on axon_radius
# [connection from Inh to Exc Neurons] Python script generated (46 lines)
# [connection from Inh to Exc Neurons] Notebook cell generated
# Executing node: connection from Exc. to Inh Neurons.
# [connection from Exc. to Inh Neurons.] Validating connection parameters...
# [connection from Exc. to Inh Neurons.] Parameter validation completed successfully
# [connection from Exc. to Inh Neurons.] Creating custom synapse model...
# [connection from Exc. to Inh Neurons.] Copying synapse model: static_synapse -> static_synapse_custom_connection_from_Exc._to_Inh_Neurons.
# [connection from Exc. to Inh Neurons.] Custom synapse model 'static_synapse_custom_connection_from_Exc._to_Inh_Neurons.' created successfully
# [connection from Exc. to Inh Neurons.] Creating NEST connections...
# [connection from Exc. to Inh Neurons.] Indegree calculation: P=1.00, Ny=800, Nx=100, alpha=50, rho=100.00
# [connection from Exc. to Inh Neurons.] Base formula: 1.00 * (800/100) * 50 = 400.00
# [connection from Exc. to Inh Neurons.] Redundancy adjustment: 400.00 / 100.00 = 4
# [connection from Exc. to Inh Neurons.] Final indegree (adjusted for redundancy): 4
# [connection from Exc. to Inh Neurons.] Using biological parameter estimation for indegree: 4
# [connection from Exc. to Inh Neurons.] Source population spatial dimensions: 3D
# [connection from Exc. to Inh Neurons.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from Exc. to Inh Neurons.] Using user-defined weight from synapse_dict
# [connection from Exc. to Inh Neurons.] Excitatory connection: weight = +4.000
# [connection from Exc. to Inh Neurons.] Connection dict: {'allow_autapses': False, 'rule': 'fixed_indegree', 'indegree': 4, 'allow_multapses': False, 'mask': {'spherical': {'radius': 0.5}}}
# [connection from Exc. to Inh Neurons.] Single synapse dict: {'synapse_model': 'static_synapse_custom_connection_from_Exc._to_Inh_Neurons.', 'weight': 4.0, 'delay': 1.0}
# [connection from Exc. to Inh Neurons.] Connecting 800 source neurons to 100 target neurons
# [connection from Exc. to Inh Neurons.] Successfully created 400 connections
# [connection from Exc. to Inh Neurons.] Connection density: 0.0050
# [connection from Exc. to Inh Neurons.] Generating Python script for connection creation...
# [connection from Exc. to Inh Neurons.] Indegree calculation: P=1.00, Ny=800, Nx=100, alpha=50, rho=100.00
# [connection from Exc. to Inh Neurons.] Base formula: 1.00 * (800/100) * 50 = 400.00
# [connection from Exc. to Inh Neurons.] Redundancy adjustment: 400.00 / 100.00 = 4
# [connection from Exc. to Inh Neurons.] Final indegree (adjusted for redundancy): 4
# [connection from Exc. to Inh Neurons.] Using biological parameter estimation for indegree: 4
# [connection from Exc. to Inh Neurons.] Source population spatial dimensions: 3D
# [connection from Exc. to Inh Neurons.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from Exc. to Inh Neurons.] Python script generated (46 lines)
# [connection from Exc. to Inh Neurons.] Generating Jupyter notebook cell...
# [connection from Exc. to Inh Neurons.] Generating Python script for connection creation...
# [connection from Exc. to Inh Neurons.] Indegree calculation: P=1.00, Ny=800, Nx=100, alpha=50, rho=100.00
# [connection from Exc. to Inh Neurons.] Base formula: 1.00 * (800/100) * 50 = 400.00
# [connection from Exc. to Inh Neurons.] Redundancy adjustment: 400.00 / 100.00 = 4
# [connection from Exc. to Inh Neurons.] Final indegree (adjusted for redundancy): 4
# [connection from Exc. to Inh Neurons.] Using biological parameter estimation for indegree: 4
# [connection from Exc. to Inh Neurons.] Source population spatial dimensions: 3D
# [connection from Exc. to Inh Neurons.] Created spherical mask with radius 0.5 based on axon_radius
# [connection from Exc. to Inh Neurons.] Python script generated (46 lines)
# [connection from Exc. to Inh Neurons.] Notebook cell generated
#
# Workflow execution completed successfully!
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
#
# Sep 27 23:44:27 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.
#
# Sep 27 23:44:27 ConnectionManager [Warning]:
#     New connections created, connection descriptors previously obtained using
#     'GetConnections' are now invalid.

# %% [markdown]
# ### Check nodes execution sequence

# %%
execution_sequence = workflow_ready.get_execution_sequence()
print(execution_sequence)
# Out:
# {'workflow_name': 'Simple population of spiking neurons', 'execution_timestamp': '2025-09-27 23:44:30', 'total_nodes': 10, 'execution_sequence': [{'node_name': 'Parvalbumin-expressing interneuron', 'node_instance': <neuroworkflow.nodes.network.SNNbuilder_SingleNeuron.SNNbuilder_SingleNeuron object at 0x176e3b770>, 'node_type': 'single_neuron_builder', 'execution_order': 0, 'timestamp': 1758984267.475772, 'duration': 0.0019462108612060547, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties']}, {'node_name': 'inhibitory cortical population', 'node_instance': <neuroworkflow.nodes.network.SNNbuilder_Population.SNNbuilder_Population object at 0x11f8db1d0>, 'node_type': 'population_builder', 'execution_order': 1, 'timestamp': 1758984267.477727, 'duration': 0.0036420822143554688, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_population', 'population_data', 'python_script', 'notebook_cell']}, {'node_name': 'pyramidal neuron', 'node_instance': <neuroworkflow.nodes.network.SNNbuilder_SingleNeuron.SNNbuilder_SingleNeuron object at 0x176e3b050>, 'node_type': 'single_neuron_builder', 'execution_order': 2, 'timestamp': 1758984267.4813771, 'duration': 0.0007207393646240234, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_neuron', 'nest_model_name', 'python_script', 'notebook_cell', 'neuron_metadata', 'biological_properties', 'nest_properties']}, {'node_name': 'cortical_population', 'node_instance': <neuroworkflow.nodes.network.SNNbuilder_Population.SNNbuilder_Population object at 0x176569910>, 'node_type': 'population_builder', 'execution_order': 3, 'timestamp': 1758984267.482102, 'duration': 0.0027642250061035156, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_population', 'population_data', 'python_script', 'notebook_cell']}, {'node_name': 'spike detector for some neurons at Inh. pop', 'node_instance': <neuroworkflow.nodes.stimulus.SNNbuilder_Recordable.SNNbuilder_Recordable object at 0x17780ea20>, 'node_type': 'recording_builder', 'execution_order': 4, 'timestamp': 1758984267.48487, 'duration': 0.0015342235565185547, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_recorders', 'python_script', 'notebook_cell', 'recording_summary', 'target_neurons']}, {'node_name': 'spike detector for Exc. pop', 'node_instance': <neuroworkflow.nodes.stimulus.SNNbuilder_Recordable.SNNbuilder_Recordable object at 0x17780df70>, 'node_type': 'recording_builder', 'execution_order': 5, 'timestamp': 1758984267.486409, 'duration': 0.0067729949951171875, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_recorders', 'python_script', 'notebook_cell', 'recording_summary', 'target_neurons']}, {'node_name': 'direct current stimulation', 'node_instance': <neuroworkflow.nodes.stimulus.SNNbuilder_Stimulation.SNNbuilder_Stimulation object at 0x1765a9400>, 'node_type': 'stimulation_builder', 'execution_order': 6, 'timestamp': 1758984267.4931872, 'duration': 0.0017237663269042969, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_stimulation_devices', 'python_script', 'notebook_cell', 'stimulation_summary', 'target_neurons']}, {'node_name': 'poisson_stimulation noise', 'node_instance': <neuroworkflow.nodes.stimulus.SNNbuilder_Stimulation.SNNbuilder_Stimulation object at 0x17780d700>, 'node_type': 'stimulation_builder', 'execution_order': 7, 'timestamp': 1758984267.494915, 'duration': 0.005883932113647461, 'success': True, 'has_python_script': True, 'has_notebook_cell': True, 'output_ports': ['nest_stimulation_devices', 'python_script', 'notebook_cell', 'stimulation_summary', 'target_neurons']}, {'node_name': 'connection from Inh to Exc Neurons' ...

# %% [markdown]
# ### Import SNNbuilder function from utils folder to generate code for simulation

# %%
from neuroworkflow.utils import export_workflow_scripts

# %% [markdown]
# ### generate code (.py and .ipynb)

# %%
files = export_workflow_scripts(
        execution_sequence=execution_sequence,
        output_dir="./",           # Custom directory
        export_python=True,                              # Export Python script
        export_notebook=True,                            # Export Jupyter notebook
        filename_base="code_gen_test3",                   # Custom filename base
        deduplicate_imports=True,                        # Remove duplicate imports
        add_metadata=True                                # Add workflow metadata
)
# Out:
# Processing workflow: Simple population of spiking neurons
# Total nodes in execution order: 10
# Processing node: Parvalbumin-expressing interneuron (has_python: True, has_notebook: True)
#   → Collected Python script (1077 chars)
#   → Collected notebook cell (1417 chars) + python script (1077 chars)
# Processing node: inhibitory cortical population (has_python: True, has_notebook: True)
#   → Collected Python script (1388 chars)
#   → Collected notebook cell (377 chars) + python script (1388 chars)
# Processing node: pyramidal neuron (has_python: True, has_notebook: True)
#   → Collected Python script (1042 chars)
#   → Collected notebook cell (1468 chars) + python script (1042 chars)
# Processing node: cortical_population (has_python: True, has_notebook: True)
#   → Collected Python script (1566 chars)
#   → Collected notebook cell (390 chars) + python script (1566 chars)
# Processing node: spike detector for some neurons at Inh. pop (has_python: True, has_notebook: True)
#   → Collected Python script (1639 chars)
#   → Collected notebook cell (1639 chars) + python script (1639 chars)
# Processing node: spike detector for Exc. pop (has_python: True, has_notebook: True)
#   → Collected Python script (972 chars)
#   → Collected notebook cell (972 chars) + python script (972 chars)
# Processing node: direct current stimulation (has_python: True, has_notebook: True)
#   → Collected Python script (1636 chars)
#   → Collected notebook cell (1851 chars) + python script (1636 chars)
# Processing node: poisson_stimulation noise (has_python: True, has_notebook: True)
#   → Collected Python script (1332 chars)
#   → Collected notebook cell (1548 chars) + python script (1332 chars)
# Processing node: connection from Inh to Exc Neurons (has_python: True, has_notebook: True)
#   → Collected Python script (1456 chars)
#   → Collected notebook cell (1697 chars) + python script (1456 chars)
# Processing node: connection from Exc. to Inh Neurons. (has_python: True, has_notebook: True)
#   → Collected Python script (1459 chars)
#   → Collected notebook cell (1699 chars) + python script (1459 chars)
#
# Summary:
#   Python script fragments: 10
#   Notebook cell fragments: 10
#   Python script exported to: ./code_gen_test3.py
#   Jupyter notebook exported to: ./code_gen_test3.ipynb

# %% [markdown]
# ### other useful commands

# %%
EI_connect.get_info()['output_ports'], EI_connect.get_output_port('connection_summary').value
# Out:
# ({'nest_connections': {'type': 'object',
#    'description': 'Created NEST connection object'},
#   'custom_synapse_model': {'type': 'str',
#    'description': 'Name of the created custom synapse model'},
#   'connection_summary': {'type': 'dict',
#    'description': 'Summary of created connections and parameters'},
#   'python_script': {'type': 'str',
#    'description': 'Generated Python script for connection creation'},
#   'notebook_cell': {'type': 'str',
#    'description': 'Generated Jupyter notebook cell'}},
#  {'source_population_size': 800,
#   'target_population_size': 100,
#   'total_connections': 400,
#   'connection_density': 0.005,
#   'connection_rule': 'fixed_indegree',
#   'synapse_model': 'static_synapse_custom_connection_from_Exc._to_Inh_Neurons.',
#   'creation_timestamp': '2025-09-27 23:11:46'})

# %%
print(my_neuron.get_output_port("python_script").value)
# Out:
# # Single Neuron: Pyramidal Neuron L2/3 (PyL23)
# # Generated by NeuroWorkflow SingleNeuronBuilderNode
# # Model Type: point_process
# # Cell Class: excitatory
#
# import nest
#
# # === BIOLOGICAL PROPERTIES ===
# # Dendrite extent: 300.0 μm
# # Dendrite diameter: 2.5 μm
# # Neurotransmitters: ['AMPA', 'NMDA']
# # PSP amplitudes: {'AMPA': 0.8, 'NMDA': 0.4}
# # Rise times: {'AMPA': 2.0, 'NMDA': 15.0}
# # Firing rates - Resting: [2.0, 8.0] Hz
# # Firing rates - Active: [15.0, 40.0] Hz
# # Firing rates - Maximum: [60.0, 120.0] Hz
#
# # === NEST MODEL CREATION ===
# nest.CopyModel("iaf_psc_alpha", "iaf_psc_alpha_PyL23_custom")
# nest.SetDefaults("iaf_psc_alpha_PyL23_custom", {
#                         "V_th": -50.0,
#                         "C_m": 200.0,
#                         "tau_m": 15.0,
#                         "V_reset": -70.0,
#                         "t_ref": 2.0,
#                         "I_e": 200.0
#                     })
# pyl23 = nest.Create("iaf_psc_alpha_PyL23_custom", 1)
#
# print(f"Created neuron: {pyl23}")
# print(f"Model template: iaf_psc_alpha_PyL23_custom")

# %%
print(my_neuron.get_output_port("notebook_cell").value)
# Out:
# # Markdown Cell
# ```markdown
# ## Neuron: Pyramidal Neuron L2/3 (PyL23)
#
# **Biological Properties:**
# - Model Type: point_process
# - Cell Class: excitatory
# - Dendrite Extent: 300.0 μm
# - Dendrite Diameter: 2.5 μm
# - Neurotransmitters: AMPA, NMDA
#
# **NEST Model:**
# - Base Model: iaf_psc_alpha
# - Custom Parameters: {'V_th': -50.0, 'C_m': 200.0, 'tau_m': 15.0, 'V_reset': -70.0, 't_ref': 2.0, 'I_e': 200.0}
# ```
#
# # Code Cell
# ```python
# # Single Neuron: Pyramidal Neuron L2/3 (PyL23)
# # Generated by NeuroWorkflow SingleNeuronBuilderNode
# # Model Type: point_process
# # Cell Class: excitatory
#
# import nest
#
# # === BIOLOGICAL PROPERTIES ===
# # Dendrite extent: 300.0 μm
# # Dendrite diameter: 2.5 μm
# # Neurotransmitters: ['AMPA', 'NMDA']
# # PSP amplitudes: {'AMPA': 0.8, 'NMDA': 0.4}
# # Rise times: {'AMPA': 2.0, 'NMDA': 15.0}
# # Firing rates - Resting: [2.0, 8.0] Hz
# # Firing rates - Active: [15.0, 40.0] Hz
# # Firing rates - Maximum: [60.0, 120.0] Hz
#
# # === NEST MODEL CREATION ===
# nest.CopyModel("iaf_psc_alpha", "iaf_psc_alpha_PyL23_custom")
# nest.SetDefaults("iaf_psc_alpha_PyL23_custom", {
#                         "V_th": -50.0,
#                         "C_m": 200.0,
#                         "tau_m": 15.0,
#                         "V_reset": -70.0,
#                         "t_ref": 2.0,
#                         "I_e": 200.0
#                     })
# pyl23 = nest.Create("iaf_psc_alpha_PyL23_custom", 1)
#
# print(f"Created neuron: {pyl23}")
# print(f"Model template: iaf_psc_alpha_PyL23_custom")
# ```

# %%
print(my_pop.get_output_port("python_script").value)
# Out:
# # Population: Layer 2/3 Pyramidal Neurons (L23Pyr)
# # Generated by NeuroWorkflow PopulationBuilderNode
# # Brain Region: Primary Visual Cortex
# # Population Size: 800 neurons (single hemisphere)
# # Model Type: point_process
# # Spatial: 3D
#
# import numpy as np
#
# # === POPULATION BIOLOGICAL CONTEXT ===
# # Density: 25000 neurons/mm³
# # Tissue volume: 0.2 mm³
# # Reference: Schüz & Palm (1989)
# # Species: human
# # Estimation method: stereological counting
# # Spatial bounds: {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)}
#
# # === SPATIAL POSITIONS ===
# # 3D positions for 800 neurons
# # Spatial bounds: {'x': (0.0, 2.0), 'y': (0.0, 2.0), 'z': (0.0, 1.0)}
#
# # Generate spatial positions
# positions = np.zeros((800, 3))
# positions[:, 0] = np.random.uniform(0.0, 2.0, 800)  # x coordinates
# positions[:, 1] = np.random.uniform(0.0, 2.0, 800)  # y coordinates
# positions[:, 2] = np.random.uniform(0.0, 1.0, 800)  # z coordinates
#
# # === POPULATION CREATION ===
# # Using neuron model from SingleNeuronBuilderNode: iaf_psc_alpha_PyL23_custom
# # Create population with 3D spatial positions
# nest_positions = nest.spatial.free(positions.tolist())
# l23pyr = nest.Create("iaf_psc_alpha_PyL23_custom", 800, positions=nest_positions)
#
# # Print status of one neuron from the population
# neuron_status = nest.GetStatus(l23pyr[0])
# print(f"Status of first neuron: {neuron_status}")
#
# # === POPULATION SUMMARY ===
# print(f"Created population: {len(l23pyr)} Layer 2/3 Pyramidal Neurons")
# print(f"Population IDs: {l23pyr}")
# print(f"Model: iaf_psc_alpha_PyL23_custom")
# print(f"Spatial organization: 3D positions")

# %%
print(my_pop.get_output_port("notebook_cell").value)
# Out:
# # Population: Layer 2/3 Pyramidal Neurons
# # 800 neurons, 3D
#
# # Create spatial positions
# positions = np.random.uniform([0.0, 0.0, 0.0], [2.0, 2.0, 1.0], (800, 3))
# nest_positions = nest.spatial.free(positions.tolist())
# l23pyr = nest.Create('iaf_psc_alpha_PyL23_custom', 800, positions=nest_positions)
# neuron_status = nest.GetStatus(l23pyr[0])
# print(f"Status of first neuron: {neuron_status}")

# %%
my_pop.get_input_port("biological_properties").get_value()
# Out:
# {'identification': {'name': 'Pyramidal Neuron L2/3',
#   'acronym': 'PyL23',
#   'model_type': 'point_process',
#   'cell_class': 'excitatory'},
#  'signaling': {'neurotransmitter_types': ['AMPA', 'NMDA'],
#   'psp_amplitudes': {'AMPA': 0.8, 'NMDA': 0.4},
#   'rise_times': {'AMPA': 2.0, 'NMDA': 15.0}},
#  'morphology': {'dendrite_extent_um': 300.0, 'dendrite_diameter_um': 2.5},
#  'activity': {'firing_rate_resting_hz': [2.0, 8.0],
#   'firing_rate_active_hz': [15.0, 40.0],
#   'firing_rate_maximum_hz': [60.0, 120.0],
#   'firing_rate_disease_hz': [0.1, 2.0]}}

# %%
print(f"Population input ports: {my_pop.get_info()['output_ports'].keys()}")
# Out:
# Population input ports: dict_keys(['nest_population', 'population_data', 'python_script', 'notebook_cell'])

# %%
my_pop.get_output_port("population_data").value
# Out:
# {'population_size': 800,
#  'name': 'Layer 2/3 Pyramidal Neurons',
#  'acronym': 'L23Pyr',
#  'model_name': 'iaf_psc_alpha_PyL23_custom',
#  'positions': array([[0.35009033, 0.92161928, 0.87127944],
#         [1.04853434, 0.58767353, 0.02763789],
#         [0.02977129, 1.61820591, 0.23041876],
#         ...,
#         [0.51034784, 1.65810333, 0.08298278],
#         [0.39637357, 1.86233676, 0.72733311],
#         [1.38457923, 1.98241354, 0.09834153]]),
#  'spatial_dimensions': '3D',
#  'biological_properties': {'identification': {'name': 'Pyramidal Neuron L2/3',
#    'acronym': 'PyL23',
#    'model_type': 'point_process',
#    'cell_class': 'excitatory'},
#   'signaling': {'neurotransmitter_types': ['AMPA', 'NMDA'],
#    'psp_amplitudes': {'AMPA': 0.8, 'NMDA': 0.4},
#    'rise_times': {'AMPA': 2.0, 'NMDA': 15.0}},
#   'morphology': {'dendrite_extent_um': 300.0, 'dendrite_diameter_um': 2.5},
#   'activity': {'firing_rate_resting_hz': [2.0, 8.0],
#    'firing_rate_active_hz': [15.0, 40.0],
#    'firing_rate_maximum_hz': [60.0, 120.0],
#    'firing_rate_disease_hz': [0.1, 2.0]}}}

# %%
biological_properties = my_pop.get_output_port("population_data").value['biological_properties']['identification']['cell_class']
print(biological_properties)
# Out:
# excitatory

# %%
EI_connect.get_info()['output_ports']
# Out:
# {'nest_connections': {'type': 'object',
#   'description': 'Created NEST connection object'},
#  'custom_synapse_model': {'type': 'str',
#   'description': 'Name of the created custom synapse model'},
#  'connection_summary': {'type': 'dict',
#   'description': 'Summary of created connections and parameters'},
#  'python_script': {'type': 'str',
#   'description': 'Generated Python script for connection creation'},
#  'notebook_cell': {'type': 'str',
#   'description': 'Generated Jupyter notebook cell'}}
